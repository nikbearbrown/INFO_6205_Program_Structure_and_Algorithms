# %% [markdown]
# **Assignment 4**

# %% [markdown]
# **Question 1:**
#
#
# Given a weighted undirected graph G = (V,E) with positive weights, a matching M is a set of edges without common vertices. A perfect matching is a matching where every vertex v € V is incident to exactly one edge in M. In other words, a perfect matching of a graph G is a set of edges which are part of G and together involve all vertices of G exactly once. If the sum of the weights of the edges in the matching is minimized, it is called a minimum-weight perfect matching.
#
# The minimum-weight perfect matching problem asks whether a given weighted undirected graph has a minimum-weight perfect matching.
#
# A. Is the minimum-weight perfect matching problem in P? If so, prove it.
#
# B. Suppose we require the matching to include exactly one edge with weight greater than a specified threshold T. We call this the constrained-weight matching problem. Is the constrained-weight matching problem in NP? If so, prove it.
#
# C. Is the constrained-weight matching problem in NP-complete? If so, prove it.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Creating a weighted undirected graph
G1 = nx.Graph()
G1.add_edge('A', 'B', weight=4)
G1.add_edge('A', 'C', weight=1)
G1.add_edge('A', 'D', weight=3)
G1.add_edge('B', 'C', weight=2)
G1.add_edge('B', 'D', weight=5)
G1.add_edge('C', 'D', weight=2)

# Plotting the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G1)
nx.draw(G1, pos, with_labels=True, node_color='lightblue', node_size=2000, font_size=20)
labels = nx.get_edge_attributes(G1, 'weight')
nx.draw_networkx_edge_labels(G1, pos, edge_labels=labels)
plt.title("Graph for Minimum-Weight Perfect Matching Problem")
plt.show()

# %% [markdown]
# Answer 1:
#
# A. Minimum-Weight Perfect Matching in P
# The minimum-weight perfect matching problem for a general graph is a well-known problem in computational graph theory. It is solvable in polynomial time using algorithms like the Blossom algorithm, developed by Jack Edmonds. This algorithm effectively finds a minimum-weight perfect matching by iteratively improving a matching using augmenting paths and shrinking cycles (blossoms) in the graph.
#
# **Example**:
#
# Imagine a graph where vertices represent people and edges represent potential partnerships, with weights indicating the cost of each partnership.
# A perfect matching would pair off all people so that everyone has a partner, and a minimum-weight perfect matching would do this at the lowest total cost.
# For instance, if you have four people (A, B, C, D) and potential partnerships (A-B, B-C, C-D, D-A, A-C, and B-D) with various costs, the Blossom algorithm would find the pairing that results in the lowest total cost while ensuring everyone is paired.
#
# B. Constrained-Weight Matching Problem in NP
# The constrained-weight matching problem, where a matching must include exactly one edge with weight greater than a specified threshold T, is in NP. The reason is that any proposed solution (a matching with one edge above the threshold) can be verified in polynomial time: check that each vertex is incident to exactly one edge and that one and only one edge has a weight greater than T.
#
# **Example**:
#
# Continuing with the same graph, now suppose we add a constraint: one of the partnerships must have a cost higher than a specific threshold.
# A solution might be a set of pairings where one specific pairing, say A-C, has a cost above the threshold.
# Verifying this is straightforward: check all pairs to ensure everyone is matched and confirm that one pair, and only one, exceeds the threshold.
#
# C. Constrained-Weight Matching Problem in NP-complete
# It's not straightforward to claim NP-completeness for this problem without a more detailed analysis or a known reduction from an NP-complete problem. NP-completeness requires proving that the problem is both in NP and NP-hard. While it's in NP (as shown in part B), the NP-hardness is not immediately clear and would require a reduction from a known NP-complete problem.
#
# **Example**:
#
# Demonstrating NP-completeness for this variant would involve a deeper theoretical analysis, possibly comparing it to other known NP-complete problems.

# %% [markdown]
# Pseudo Code:
#
# The Blossom Algorithm is typically used for finding a minimum-weight perfect matching in a general graph. However, it is quite complex. Here is a simplified conceptual pseudocode:
#
# ```
# function BlossomAlgorithm(Graph G):
#     Initialize an empty matching M
#     while there are augmenting paths relative to M in G:
#         Find the shortest augmenting path P
#         Augment the matching along P
#     return M
# ```
#
# For the constrained problem where one edge must have a weight greater than a threshold, the pseudocode would include an additional check:
#
#
#
# ```
# function ConstrainedMatching(Graph G, Threshold T):
#     M = BlossomAlgorithm(G)
#     if any edge in M has a weight > T:
#         return M
#     else:
#         Modify G or M to meet the threshold requirement
#         return Modified M
# ```

# %% [markdown]
# **Question 2:**
#
# Consider a finite, undirected graph G = (V,E) where each edge e in E has an associated color. A color-spanning subgraph is a subgraph of G such that every color represented in E is also present in the subgraph. A minimum-edge color-spanning subgraph is a color-spanning subgraph that has the fewest possible edges.
#
# The minimum-edge color-spanning subgraph problem asks whether a given graph G has a color-spanning subgraph with the minimum number of edges.
#
# A. Is the minimum-edge color-spanning subgraph problem in P? If so, prove it.
#
# B. Suppose each vertex in the graph must be connected to edges of at least two different colors. We call this the multi-color connectivity problem. Is the multi-color connectivity problem in NP? If so, prove it.
#
# C. Is the multi-color connectivity problem in NP-complete? If so, prove it.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Creating an undirected graph with colored edges
G2 = nx.Graph()
G2.add_edge('A', 'B', color='red')
G2.add_edge('A', 'C', color='blue')
G2.add_edge('B', 'C', color='green')
G2.add_edge('B', 'D', color='red')
G2.add_edge('C', 'D', color='blue')
G2.add_edge('D', 'A', color='green')

# Extracting colors for visualization
colors = [G2[u][v]['color'] for u, v in G2.edges()]

# Plotting the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G2)
nx.draw(G2, pos, edge_color=colors, with_labels=True, node_color='lightblue', node_size=2000, font_size=20)
plt.title("Graph for Minimum-Edge Color-Spanning Subgraph Problem")
plt.show()

# %% [markdown]
# **Answer 2:**
#
# A. Minimum-Edge Color-Spanning Subgraph in P
# The decision version of the minimum-edge color-spanning subgraph problem (whether there exists a color-spanning subgraph with at most k edges) can be NP-hard, depending on how the colors are assigned and the structure of the graph. For simple cases, it might be in P, but in general, finding the exact complexity class would require a specific graph structure or color assignment scheme.
#
# **Example**:
#
# Consider a graph where vertices are cities, and edges are roads colored based on their type (highway, local road, etc.).
# A color-spanning subgraph would be a network of roads including at least one of each type.
# The minimum-edge color-spanning subgraph finds the smallest such network.
# If each road type must be present, the problem could become complex, depending on how roads are distributed and connected.
#
# B. Multi-Color Connectivity Problem in NP
# The multi-color connectivity problem is in NP. Given a solution (a subgraph where each vertex is connected to edges of at least two different colors), it can be verified in polynomial time by checking the color of edges incident to each vertex.
#
# **Example**:
#
# Extend the city graph example, but now every city must be connected to at least two different types of roads.
# A solution might be a subgraph where each city has access to, say, a highway and a local road.
# Verifying this involves checking the connections of each city to ensure they meet the two-color road requirement.
#
# C. Multi-Color Connectivity Problem in NP-complete
# As with the constrained-weight matching problem, asserting NP-completeness for the multi-color connectivity problem is non-trivial. It requires establishing that the problem is NP-hard, which typically involves demonstrating a reduction from a known NP-complete problem. The complexity might vary based on the graph's structure and the color distribution among the edges.
#
# **Example**:
#
# Proving NP-completeness would require a more complex theoretical approach, similar to what's needed in Question 2C.

# %% [markdown]
# Pseudo Code:
#
# For finding a minimum-edge color-spanning subgraph, one approach is to use a greedy algorithm. This is a conceptual pseudocode:
#
# ```
# function MinEdgeColorSpanningSubgraph(Graph G):
#     Subgraph S = empty subgraph of G
#     For each color c in G:
#         Find the shortest edge of color c
#         Add this edge to S if it does not create a cycle
#     return S
# ```
#
# For the multi-color connectivity problem, the algorithm needs to ensure that each vertex is connected to edges of at least two different colors:
#
# ```
# function MultiColorConnectivity(Graph G):
#     Subgraph S = MinEdgeColorSpanningSubgraph(G)
#     For each vertex v in G:
#         If v is not connected to at least two different colored edges in S:
#             Find the shortest edge connecting v with a new color
#             Add this edge to S if it does not create a cycle
#     return S
# ```

# %% [markdown]
# **Question 3:**
#
# The Directed Vertex Cover Problem is defined as follows. We are given a directed graph G and an integer k. The problem is to decide whether there exists a set of at most k vertices in G such that every edge in G is incident to at least one vertex in the set.
#
# Demonstrate that the Directed Vertex Cover Problem is NP-complete.

# %% [markdown]
# **Answer 3:**
#
# Proving NP-Completeness of the Directed Vertex Cover Problem
#
# Showing that Directed Vertex Cover is in NP:
#
# A problem is in NP if a solution to it can be verified in polynomial time.
# For the Directed Vertex Cover Problem, given a set of vertices, we can efficiently check if every edge in the graph is incident to at least one vertex in this set. This verification involves examining each edge against the set of selected vertices, a task that can be accomplished in polynomial time relative to the graph's size.
# Demonstrating Directed Vertex Cover is NP-hard:
#
# Establishing NP-hardness typically involves reducing a known NP-complete problem to the problem in question. The Vertex Cover Problem, known to be NP-complete, is often used for such reductions.
# Reduction Process from Vertex Cover to Directed Vertex Cover:
# Begin with an instance of the Vertex Cover Problem: an undirected graph G' and an integer k.
# Transform this into an instance of the Directed Vertex Cover Problem. For each edge (u, v) in G', create two directed edges (u, v) and (v, u) in a new directed graph G.
# The graph G and the integer k form the instance for the Directed Vertex Cover Problem.
# This conversion can be executed in polynomial time.
# If a vertex cover of size k exists in G', the same set of vertices will suffice for covering all directed edges in G. Conversely, a vertex cover in G implies a vertex cover in G'.
# By showing that the Directed Vertex Cover Problem is in NP and that an instance of the NP-complete Vertex Cover Problem can be polynomially reduced to an instance of the Directed Vertex Cover Problem, we prove that the Directed Vertex Cover Problem is NP-complete.

# %% [markdown]
# Pseudo Code:
#
# ```
# Algorithm DirectedVertexCover(G, k)
#     Input: A directed graph G(V, E), an integer k
#     Output: A set of vertices that form a vertex cover of size at most k, if it exists
#
#     1. If k < 0, return NO SOLUTION (since we cannot have a negative number of vertices)
#     2. If E is empty, return EMPTY SET (since no vertices are needed to cover an empty set of edges)
#
#     3. For each vertex v in V:
#         a. Create a new graph G' by removing v and all edges incident to v from G
#         b. Recursively call DirectedVertexCover(G', k - 1)
#         c. If the recursive call returns a solution S:
#             i. Add v to S
#             ii. Return S
#
#     4. Return NO SOLUTION (if no vertex cover of size at most k is found)
#
# // Main execution
# G = [Graph input]
# k = [Size input]
# result = DirectedVertexCover(G, k)
#
# if result is NO SOLUTION:
#     Print "No vertex cover of size k exists."
# else:
#     Print "Vertex cover of size k found: ", result
#
# ```

# %% [markdown]
# **Question 4:**
#
# The Directed Cycle Cover Problem is defined as follows: Given a directed graph G, the task is to decide whether there exists a set of vertex-disjoint cycles that together cover all the vertices of G.
#
# Demonstrate that the Directed Cycle Cover Problem is NP-complete.

# %% [markdown]
# **Answer 4:**
#
# The Directed Cycle Cover Problem is defined as follows: Given a directed graph G, determine if there exists a set of vertex-disjoint cycles that together cover all the vertices of G. Prove that this problem is NP-complete.
#
# Solution
# 1. Showing that Directed Cycle Cover is in NP:
#
# A problem is in NP if a given solution can be verified in polynomial time.
# For the Directed Cycle Cover Problem, given a set of cycles, it can be verified in polynomial time whether these cycles are vertex-disjoint and cover all vertices in G.
# 2. Showing that Directed Cycle Cover is NP-hard:
#
# Use reduction from the Hamiltonian Cycle Problem, which is known to be NP-complete.
# Reduction from Hamiltonian Cycle to Directed Cycle Cover:
# Take an instance of the Hamiltonian Cycle Problem (a directed graph G').
# Use the same graph as an instance for the Directed Cycle Cover Problem.
# A Hamiltonian cycle in G' would be a valid cycle cover in G, covering all vertices with a single cycle.
# Conversely, if a directed graph has a cycle cover covering all vertices, it implies the existence of a Hamiltonian cycle if the cover consists of exactly one cycle.

# %% [markdown]
# **Pseudo code:**
#
# ```
# Algorithm VerifyDirectedCycleCover(G, Cycles)
#     Input: A directed graph G(V, E), a set of cycles Cycles
#     Output: True if Cycles form a valid cycle cover of G, False otherwise
#
#     1. Create a set CoveredVertices to keep track of covered vertices.
#     2. For each cycle in Cycles:
#         a. For each vertex v in the cycle:
#             i. If v is already in CoveredVertices, return False (as cycles are not disjoint).
#             ii. Add v to CoveredVertices.
#     3. If CoveredVertices contains all vertices in V, return True.
#     4. Else, return False.
#
# // Main execution
# G = [Graph input]
# Cycles = [Set of cycles input]
# result = VerifyDirectedCycleCover(G, Cycles)
#
# if result:
#     Print "The cycles form a valid cycle cover."
# else:
#     Print "The cycles do not form a valid cycle cover."
#
# ```

# %% [markdown]
# **Question 5:**
#
# The Cheapest Teacher Set Problem is defined as follows: You are organizing a game development workshop and need instructors proficient in each of the n required skills for game development (like programming, art, animation, modeling, artificial intelligence, and analytics). You have m potential instructors, each skilled in a subset of these skills. The question is: For a given number k ≤ m, is it possible to hire at most k instructors who collectively possess all n required skills? This is known as the Cheapest Teacher Set Problem.

# %% [markdown]
# **Answer 5:**
#
# Cheapest Teacher Set is in NP:
#
# A problem is in NP if a given solution can be verified quickly (in polynomial time).
# For the Cheapest Teacher Set Problem, given a set of k instructors, we can verify in polynomial time if between them they cover all n skills. This involves checking each skill against the skillsets of the selected instructors.
# Cheapest Teacher Set is NP-hard:
#
# To show NP-hardness, we typically reduce a known NP-complete problem to our problem. In this case, we can use the Set Cover Problem, which is known to be NP-complete.
# Reduction from Set Cover to Cheapest Teacher Set:
# Given an instance of the Set Cover Problem (a universe of elements and a collection of sets), interpret each element as a required skill and each set as a potential instructor's skillset.
# The task in the Set Cover Problem of covering all elements with a minimum number of sets parallels hiring the smallest number of instructors to cover all skills.
# Thus, a solution to the Set Cover Problem provides a solution to the Cheapest Teacher Set Problem, and vice versa.
#
# Conclusion:
# By demonstrating that the Cheapest Teacher Set Problem is in NP and that it is as hard as the Set Cover Problem (an NP-complete problem), we establish that the Cheapest Teacher Set Problem is NP-complete.

# %% [markdown]
# **Pseudo Code:**
#
# ```
# Algorithm VerifyCheapestTeacherSet(Instructors, Skills, k)
#     Input: A set of potential instructors Instructors, each with their own set of skills,
#            A set of required skills Skills,
#            An integer k representing the maximum number of instructors to hire
#     Output: True if it is possible to hire at most k instructors that cover all skills, False otherwise
#
#     1. If the size of Instructors is greater than k, return False (as we cannot hire more than k instructors)
#
#     2. Create a set CoveredSkills to keep track of covered skills
#
#     3. For each instructor in Instructors:
#         a. Add the skills of this instructor to CoveredSkills
#
#     4. For each skill in Skills:
#         a. If this skill is not in CoveredSkills, return False (as not all skills are covered)
#
#     5. Return True (all skills are covered with at most k instructors)
#
# // Main execution
# Instructors = [Set of potential instructors with their skills]
# Skills = [Set of required skills]
# k = [Maximum number of instructors to hire]
#
# result = VerifyCheapestTeacherSet(Instructors, Skills, k)
#
# if result:
#     Print "It is possible to hire at most k instructors to cover all skills."
# else:
#     Print "It is not possible to hire at most k instructors to cover all skills."
#
# ```

# %% [markdown]
# **Question 6:**
#
# The Optimal Workshop Schedule Problem is defined as follows: You are organizing a series of technical workshops, each requiring a specific set of expertise areas (like cloud computing, cybersecurity, data science, etc.). You have a pool of n experts, each with expertise in a variety of these areas. The goal is to determine, for a given number k ≤ n, whether it's possible to schedule at most k experts in such a way that each workshop has at least one expert in its required expertise area. This challenge is known as the Optimal Workshop Schedule Problem.

# %% [markdown]
# **Answer 6:**
#
# Optimal Workshop Schedule is in NP:
#
# A problem is in NP if any given solution can be verified quickly (in polynomial time).
# For the Optimal Workshop Schedule Problem, given a set of k experts, you can verify in polynomial time whether these experts collectively cover all the expertise areas required by the workshops. This involves checking each workshop’s requirements against the expertise of the selected experts.
# Optimal Workshop Schedule is NP-hard:
#
# To prove NP-hardness, a known NP-complete problem is typically reduced to the problem in question. For this scenario, the Set Cover Problem, which is NP-complete, can be used for reduction.
# Reduction from Set Cover to Optimal Workshop Schedule:
# Take an instance of the Set Cover Problem (a universe of elements and a collection of sets) and interpret each element as a required expertise area and each set as the expertise profile of a potential expert.
# The task of covering all elements in the Set Cover Problem with a minimum number of sets parallels scheduling the fewest experts to cover all required expertise areas in the workshops.
# Thus, a solution to the Set Cover Problem is equivalent to a solution to the Optimal Workshop Schedule Problem and vice versa.
#
# By demonstrating that the Optimal Workshop Schedule Problem is in NP and that it can be transformed from the Set Cover Problem, we establish that the Optimal Workshop Schedule Problem is NP-complete.

# %% [markdown]
# **Pseudo Code:**
#
# ```
# Algorithm VerifyOptimalWorkshopSchedule(Experts, Workshops, k)
#     Input: A set of experts Experts, each with their own expertise areas,
#            A set of workshops Workshops, each requiring specific expertise areas,
#            An integer k representing the maximum number of experts to schedule
#     Output: True if it is possible to schedule at most k experts covering all workshops, False otherwise
#
#     1. If the size of Experts is greater than k, return False (can't schedule more than k experts)
#
#     2. Create a set CoveredWorkshops to keep track of covered workshops
#
#     3. For each expert in Experts:
#         a. For each workshop in Workshops:
#             i. If the expert covers the required expertise area of the workshop:
#                 - Add the workshop to CoveredWorkshops
#
#     4. If CoveredWorkshops contains all workshops in Workshops, return True
#     5. Else, return False
#
# // Main execution
# Experts = [Set of experts with their expertise areas]
# Workshops = [Set of workshops with required expertise areas]
# k = [Maximum number of experts to schedule]
#
# result = VerifyOptimalWorkshopSchedule(Experts, Workshops, k)
#
# if result:
#     Print "It is possible to schedule at most k experts covering all workshops."
# else:
#     Print "It is not possible to schedule at most k experts covering all workshops."
#
# ```

# %% [markdown]
# **Question 7:**
#
# Suppose you are involved in organizing a summer sports camp, which leads to the following challenge. The camp needs to ensure that there is at least one counselor skilled in each of the n sports offered at the camp (like baseball, volleyball, etc.). There are m potential counselors who have applied, and for each sport, only a subset of these applicants is qualified. The question is: For a specified number k < m, is it possible to hire at most k counselors such that every one of the n sports has at least one qualified counselor? This scenario is referred to as the Efficient Recruiting Problem.

# %% [markdown]
# **Answer 7:**
#
# The Efficient Recruiting Problem, in the context of organizing a summer sports camp, involves finding the minimum number of counselors who can cover all the required sports. Let's break it down with an example for better understanding.
#
# Example Scenario:
#
# Sports at Camp: Baseball, Volleyball, Swimming, Archery (i.e., n=4 sports).
# Applicants (Counselors):
# Counselor A: Skilled in Baseball, Volleyball.
# Counselor B: Skilled in Swimming.
# Counselor C: Skilled in Archery, Baseball.
# Counselor D: Skilled in Volleyball, Swimming, Archery.
# (Thus, m=4 potential counselors).
#
# Problem Statement:
#
# Is it possible to hire at most k counselors (where k<m, say k=2) such that each sport (Baseball, Volleyball, Swimming, Archery) has at least one qualified counselor?
#
# Analysis with the Example:
#
# To cover all sports with at most 2 counselors, we need to check combinations of counselors whose collective skills encompass all four sports.
# One possible combination is Counselor A (Baseball, Volleyball) and Counselor B (Swimming), but this leaves Archery uncovered.
# Another combination is Counselor C (Archery, Baseball) and Counselor D (Volleyball, Swimming, Archery), which covers all sports. Thus, hiring Counselor C and D would be a solution.
# Showing NP-completeness:
#
# In NP:
# Given a set of counselors (like C and D in our example), we can quickly verify if they cover all sports. This involves checking each counselor's skills against the list of sports, which is a polynomial-time task.
# NP-hard:
# We can relate this to the Set Cover Problem. In our example, each sport is an element in the universe (Set Cover Problem), and each counselor's skill set represents a set in the collection. The goal is to cover all elements (sports) with the fewest number of sets (counselors).
# If we can solve the Set Cover Problem, we can solve the Efficient Recruiting Problem and vice versa, implying the latter's NP-hardness.
# By understanding this problem through a practical example and relating it to the Set Cover Problem, we can see why the Efficient Recruiting Problem is considered NP-complete. The complexity lies in finding the optimal group of counselors that covers all sports, especially as the number of sports and applicants increases.

# %% [markdown]
# Pseudo code:
#
# ```
# Algorithm VerifyEfficientRecruiting(Counselors, Sports, k)
#     Input: A set of potential counselors Counselors, each with their skills in various sports,
#            A set of required sports Sports,
#            An integer k representing the maximum number of counselors to hire
#     Output: True if it is possible to hire at most k counselors covering all sports, False otherwise
#
#     1. If the size of Counselors is greater than k, return False (can't hire more than k counselors)
#
#     2. Create a set CoveredSports to keep track of covered sports
#
#     3. For each counselor in Counselors:
#         a. Add the sports the counselor is skilled in to CoveredSports
#
#     4. For each sport in Sports:
#         a. If this sport is not in CoveredSports, return False (as not all sports are covered)
#
#     5. Return True (all sports are covered with at most k counselors)
#
# // Main execution
# Counselors = [Set of counselors with their sports skills]
# Sports = [Set of required sports]
# k = [Maximum number of counselors to hire]
#
# result = VerifyEfficientRecruiting(Counselors, Sports, k)
#
# if result:
#     Print "It is possible to hire at most k counselors to cover all sports."
# else:
#     Print "It is not possible to hire at most k counselors to cover all sports."
#
# ```

# %% [markdown]
# **Question 8:**
#
# Imagine you're involved in organizing an academic tutoring program, and you face the following challenge. The program is supposed to have at least one tutor skilled in each of the n subjects it offers (like mathematics, physics, chemistry, literature, etc.). You have received job applications from m potential tutors. For each of the n subjects, there is some subset of the m applicants qualified to tutor in that subject. The question is: For a given number k < m, is it possible to hire at most k of the tutors and have at least one tutor qualified in each of the n subjects? This scenario is referred to as the Efficient Academic Tutoring Problem.

# %% [markdown]
# **Answer 8:**
#
# Understanding the Problem:
# The Efficient Academic Tutoring Problem requires finding a subset of tutors such that each of the n subjects offered by the tutoring program is covered, with the constraint of hiring at most k tutors.
#
# Example Scenario:
# Subjects (n = 3): Mathematics, Physics, Chemistry.
#
# Applicants (m = 4):
#
# Tutor 1: Qualified in Mathematics, Physics.
# Tutor 2: Qualified in Chemistry.
# Tutor 3: Qualified in Physics, Chemistry.
# Tutor 4: Qualified in Mathematics.
# Hiring Constraint: k = 2 (Hire at most 2 tutors).
#
# Problem Statement:
# Is it possible to hire at most 2 tutors such that each of the three subjects (Mathematics, Physics, Chemistry) is covered?
#
# Analysis with the Example:
# Mathematics: Can be covered by Tutor 1 or Tutor 4.
# Physics: Can be covered by Tutor 1 or Tutor 3.
# Chemistry: Can be covered by Tutor 2 or Tutor 3.
# A possible solution is to hire Tutor 1 (covering Mathematics and Physics) and Tutor 2 (covering Chemistry). This satisfies the constraint of hiring at most 2 tutors while covering all subjects.

# %% [markdown]
# **Pseudo code:**
#
# ```
# Algorithm VerifyEfficientTutoring(Tutors, Subjects, k)
#     Input: A list of Tutors, each with their qualified subjects,
#            A set of Subjects to be covered,
#            An integer k representing the maximum number of tutors to hire
#     Output: True if a valid hiring solution exists, False otherwise
#
#     1. If the number of Tutors is greater than k, return False
#
#     2. Initialize an empty set CoveredSubjects
#
#     3. For each tutor in Tutors:
#         a. Add the subjects they can tutor to CoveredSubjects
#
#     4. If CoveredSubjects contains all Subjects, return True
#     5. Else, return False
#
# // Main execution
# Tutors = [List of tutors with their qualified subjects]
# Subjects = [List of subjects to be covered]
# k = [Maximum number of tutors to hire]
#
# result = VerifyEfficientTutoring(Tutors, Subjects, k)
#
# if result:
#     Print "A valid tutoring solution exists."
# else:
#     Print "No valid tutoring solution is possible."
#
# ```

# %% [markdown]
# **Question 9:**
#
# Imagine you're living in the Ice-Cream and Rainbows Cooperative apartment with n−1 other people. Over the next n nights, each resident is expected to cook dinner exactly once, ensuring that someone cooks each night. However, everyone has scheduling conflicts on some nights (like exams, concerts, etc.), making it a challenging task to decide who should cook on which night. Let's define the people as P in the set {p1, …, pn}, the nights as N in the set {n1, …, nn}, and for each person pi, there’s a set Si of nights when they are not able to cook. Note that Si cannot be empty for any person. If a person isn't scheduled to cook on any of the n nights, they must pay $100 to hire a cook.
#
# The question is: Can a schedule be created where each person cooks exactly once, on a night they are available, such that all n nights are covered?

# %% [markdown]
# **Answer 9:**
#
# Understanding the Problem:
# The Co-op Dinner Scheduling Problem involves arranging a schedule for n people to cook over n nights, with each person cooking exactly once, on a night when they are available. The complexity lies in the constraints - each person has specific nights they cannot cook, and if they don't get scheduled, there is a cost of $100 for hiring a cook.
#
# Example Scenario:
# Residents (n = 3):
#
# Person 1 (P1): Cannot cook on Night 1.
# Person 2 (P2): Cannot cook on Night 2.
# Person 3 (P3): Cannot cook on Night 3.
# Nights (N = 3): Night 1, Night 2, Night 3.
#
# Problem Statement:
# Is it possible to schedule each of the three residents to cook on one of the three nights, considering their availability?
# Analysis with the Example:
# Night 1: P2 and P3 are available. Let's schedule P2.
# Night 2: P1 and P3 are available. Since P2 already cooked, we can schedule P1.
# Night 3: Only P3 is available and hasn't cooked yet, so we schedule P3.
# This schedule covers all three nights with each resident cooking once on a night they are available.
#
# Showing NP-Completeness:
# In NP:
#
# Given a schedule, it is straightforward to verify if each person is scheduled on a night they are available and that all nights are covered. This verification can be done in polynomial time.
# NP-hard:
#
# The problem can be related to known NP-complete problems like 3-Dimensional Matching, where solving one can provide a solution to the other.
# In the 3-Dimensional Matching problem, each triplet represents a possible assignment of a person to a night. Finding a complete matching without repetitions parallels the challenge of scheduling each person on a different night.
# Conclusion:
# Through this example, we see that the Co-op Dinner Scheduling Problem is in NP and shares characteristics with NP-hard problems, making it NP-complete. The challenge is in devising a schedule that meets all the constraints, which becomes increasingly difficult as the number of residents and their unavailable nights increase.

# %% [markdown]
# **Pseudo Code:**
#
# ```
# Algorithm VerifyCoopDinnerSchedule(Residents, Nights, Availability, k)
#     Input: A list of Residents,
#            A list of Nights,
#            A dictionary Availability mapping each Resident to a list of Nights they are available,
#            An integer k representing the number of Residents
#     Output: True if a valid schedule exists, False otherwise
#
#     1. Initialize an empty dictionary Schedule
#
#     2. For each night in Nights:
#         a. Initialize an empty list PossibleCooks
#         b. For each resident in Residents:
#             i. If the night is in the resident's list of available nights in Availability:
#                 - Add the resident to PossibleCooks
#         c. If PossibleCooks is empty, return False (no one available to cook)
#         d. Select a resident from PossibleCooks and assign them to cook on this night
#         e. Add the resident-night pair to Schedule
#         f. Remove the selected resident from Residents to ensure they don't cook again
#
#     3. If all Nights are covered in Schedule and each Resident cooks exactly once:
#         a. Return True
#     4. Else:
#         a. Return False
#
# // Main execution
# Residents = [List of residents]
# Nights = [List of nights]
# Availability = [Availability of each resident on each night]
# k = [Number of residents]
#
# result = VerifyCoopDinnerSchedule(Residents, Nights, Availability, k)
#
# if result:
#     Print "A valid schedule exists."
# else:
#     Print "No valid schedule is possible."
#
# ```

# %% [markdown]
# **Question 10:**
#
# Suppose you live in a shared house with n - 1 other roommates. To keep the house in order, a list of n different chores must be completed each week, with each chore assigned to one roommate. However, every roommate has certain chores they are either unable or unwilling to do. For each roommate r_i, there's a set C_i of chores they cannot or will not perform. The set C_i cannot be empty for any roommate.
#
# The question is: Can an assignment be made where each roommate is responsible for exactly one chore each week, and every chore is assigned, ensuring that no roommate is given a chore from their unable/unwilling list?
#
# This challenge is known as the Efficient Roommate Chore Assignment Problem.

# %% [markdown]
# **Answer 10:**
#
# Understanding the Problem:
# The Efficient Roommate Chore Assignment Problem involves allocating a set of chores to roommates in such a way that each roommate does a chore they are willing and able to do, with each chore assigned to one person only. The complexity lies in the constraints of each roommate's preferences or limitations.
#
# Example Scenario:
# Roommates (n = 4):
#
# Roommate 1 (R1): Cannot or will not do Dishes and Vacuuming.
# Roommate 2 (R2): Cannot or will not do Laundry.
# Roommate 3 (R3): Cannot or will not do Cooking.
# Roommate 4 (R4): Cannot or will not do Gardening.
# Chores (n = 4): Dishes, Vacuuming, Laundry, Cooking, Gardening.
#
# Problem Statement:
# Is it possible to assign each of the four chores to the four roommates, considering their constraints?
# Analysis with the Example:
# Dishes: Can be done by R2, R3, or R4. Let's assign it to R2.
# Vacuuming: Can be done by R2, R3, or R4. R2 is already assigned Dishes, so we assign Vacuuming to R3.
# Laundry: Can be done by R1, R3, or R4. R3 is already assigned Vacuuming, so we assign Laundry to R1.
# Cooking: Can be done by R1, R2, or R4. R1 and R2 have chores, so we assign Cooking to R4.
# This assignment covers all chores with each roommate doing one chore they can perform.
#
# Showing the Solution:
# Each roommate is assigned exactly one chore.
# No roommate is assigned a chore from their unable/unwilling list.
# All chores are assigned and accounted for.
# Conclusion:
# Through this example, we demonstrate a feasible solution to the Efficient Roommate Chore Assignment Problem. The problem becomes increasingly complex with more roommates and a larger set of chores, especially as the number of constraints (chores a roommate cannot or will not do) increases. The challenge is in finding an assignment that meets all these constraints, a task that might not always have a straightforward solution.

# %% [markdown]
# **Pseudo Code:**
#
# ```
# Algorithm VerifyRoommateChoreAssignment(Roommates, Chores, UnwillingTasks, n)
#     Input: A list of Roommates,
#            A list of Chores,
#            A dictionary UnwillingTasks mapping each Roommate to a list of Chores they cannot or will not perform,
#            An integer n representing the number of Roommates and Chores
#     Output: True if a valid assignment exists, False otherwise
#
#     1. Initialize an empty dictionary ChoreAssignment
#
#     2. For each chore in Chores:
#         a. Initialize an empty list AvailableRoommates
#         b. For each roommate in Roommates:
#             i. If the chore is not in the roommate's list of unwilling tasks in UnwillingTasks:
#                 - Add the roommate to AvailableRoommates
#         c. If AvailableRoommates is empty, return False (no one available to perform this chore)
#         d. Select a roommate from AvailableRoommates and assign them this chore
#         e. Add the roommate-chore pair to ChoreAssignment
#         f. Remove the selected roommate from Roommates to ensure they don't get assigned another chore
#
#     3. If all Chores are covered in ChoreAssignment and each Roommate is assigned exactly one chore:
#         a. Return True
#     4. Else:
#         a. Return False
#
# // Main execution
# Roommates = [List of roommates]
# Chores = [List of chores]
# UnwillingTasks = [Unwilling tasks of each roommate]
# n = [Number of roommates]
#
# result = VerifyRoommateChoreAssignment(Roommates, Chores, UnwillingTasks, n)
#
# if result:
#     Print "A valid chore assignment exists."
# else:
#     Print "No valid chore assignment is possible."
#
# ```

# %% [markdown]
# **How ChatGPT or the tool you used assisted in this task:**
#
# Assistance of ChatGPT in Algorithmic Tasks:
# My engagement with ChatGPT was invaluable in navigating the complexities of algorithmic problems such as the vertex-disjoint cycle-cover and 3-cycle-cover problems. ChatGPT acted as an indispensable ally, breaking down intricate ideas and providing clarity during moments of uncertainty. Whether it was understanding the intricacies of NP-completeness in the Directed Disjoint Paths Problem or comprehending the subtleties of conflict connection gadgets in the 3-cycle-cover problem, ChatGPT was a crucial aid. Its explanatory prowess was particularly evident in topics like the Set Cover problem transformed into the Cheapest Teacher problem, resembling the support of a personal tutor. ChatGPT's interactive approach fostered a deeper and more holistic understanding of each algorithmic challenge​​.
#
# Challenges in Maintaining the Essence of Algorithmic Problems:
# While engaging with the nuances of algorithms like the 3-cycle-cover problem and the Directed Disjoint Paths Problem, I recognized the importance of preserving the original essence of these complex problems. A major challenge was avoiding oversimplification or alteration that might detract from their inherent complexity or significance. Striking a balance between comprehensibility and retaining the core essence was a delicate task. Another challenge was avoiding generic or overly complicated solutions, which could diminish the educational value. The effort to maintain adaptability while adhering to the fundamental principles of each algorithm was a continuous process​​.
#
# Learnings on Problem Design in Algorithms:
# Delving into the complex field of algorithms, such as exploring the vertex-disjoint cycle-cover problem or understanding the polynomial-time solutions for approximate problems, provided rich insights into problem design. I learned that a well-constructed problem should be intellectually stimulating and illuminating, promoting critical thought while guiding toward deeper comprehension. For instance, the construction of the maximum flow problem for scheduling tasks revealed the beauty of problem decomposition and optimization. The exploration of NP-completeness in problems like the 3-cycle-cover and Cheapest Teacher highlighted the importance of efficiency and strategic thinking in problem-solving. Each algorithmic challenge reinforced that the essence of problem design is to foster learning and challenge existing knowledge boundaries​​.
