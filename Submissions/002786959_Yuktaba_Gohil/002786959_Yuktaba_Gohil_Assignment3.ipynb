# %% [markdown]
# #Assignment 3

# %% [markdown]
# **Question1**<br>
# **Give a brief definitions for the following:**
#
# **i. Merge Sort<br>
# ii. Hash Table<br>
# iii. Depth-First Search (DFS)<br>
# iv. Binary Search Tree (BST)<br>
# v. Dijkstra's Algorithm<br>**

# %% [markdown]
# ***Solution:***
#
# i. Merge Sort<br>
# The Merge Sort algorithm is a comparison-based sorting method that follows the divide-and-conquer programming approach. It divides an unsorted list into sub-lists until they each contain one element, then repeatedly merges the sub-lists until only one sorted list remains.
#
# ii. Hash Table<br>
# A Hash Table is a data structure that stores key-value pairs, allowing for efficient retrieval of values based on their associated keys. It uses a hash function to map keys to specific locations in memory.
#
# iii. Depth-First Search (DFS)<br>
# Depth-First Search is an algorithm used to traverse or search a graph or tree data structure by exploring as far as possible along each branch before backtracking. It's often used to find connected components or paths in graphs.
#
# iv. Binary Search Tree (BST)<br>
# A Binary Search Tree is a binary tree data structure in which each node has at most two children. It follows a specific ordering property where values to the left of a node are smaller, and values to the right are larger, making it useful for efficient searching and sorting.
#
# v. Dijkstra's Algorithm<br>
# Dijkstra's Algorithm is a graph traversal algorithm used to find the shortest path from a single source node to all other nodes in a weighted graph. It works for graphs with non-negative edge weights and is commonly used in network routing and navigation systems.
#
# **Reflection Quality**
#
# + I used chatGPT to create similar question to the one given in worked solutions.<br>
# + I then searched the definitions on Google and chose the one that was easy to understand.

# %% [markdown]
# **Question2**<br>
# Use the Bellman-Ford algorithm to find the shortest path from node A to F in the weighted directed graph below. Show your work.
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ques1.png?raw=true)

# %% [markdown]
# ***Solution:***
#
# Principle of Relaxation of Edges for Bellman-Ford:
#
# + As we can see in the graph, the graph has 6 Vertices, all the edges should be relaxed 5 times to compute the single source shortest path.<br>
# + In order to detect whether a negative cycle exists or not, relax all the edge one more time and if the shortest distance for any node reduces then we can say that a negative cycle exists. In short if we relax the edges 6 times, and there is any change in the shortest distance of any node between the 5th and 6th relaxation than a negative cycle exists, otherwise not exist.
#
# Lets start solving the question.
#
# Step 1: Initialize a distance array Dist[] to store the shortest distance for each vertex from the source vertex. Initially distance of source will be 0 and Distance of other vertices will be INFINITY. We will take node A as source.
#
# | A  | B  | C  | D  | E  | F  |
# | -- | -- | -- | -- | -- | -- |
# | 0  |  &infin;  |  &infin;  |  &infin;  |  &infin;  |  &infin;  |
#
# Step 2: Start relaxing the edges, during 1st Relaxation:<br>
# + Current Distance of B > (Distance of A) + (Weight of A to B) i.e. Infinity > 0 + 7
# + Therefore, Dist[B] = 7
#
# | A  | B  | C  | D  | E  | F  |
# | -- | -- | -- | -- | -- | -- |
# | 0  |  7  |  &infin;  |  &infin;  |  &infin;  |  &infin;  |
#
# Step 3: During 2nd Relaxation:<br>
# + Current Distance of D > (Distance of B) + (Weight of B to D) i.e. Infinity > 7 + 4
# Dist[D] = 11<br>
# + Current Distance of C > (Distance of B) + (Weight of B to C) i.e. Infinity > 7 + 3
# Dist[C] = 10
#
# | A  | B  | C  | D  | E  | F  |
# | -- | -- | -- | -- | -- | -- |
# | 0  |  7  |  10  |  11  |  &infin;  |  &infin;  |
#
# Step 4: During 3rd Relaxation:<br>
# + Current Distance of F > (Distance of D ) + (Weight of D to F) i.e. Infinity > 11 + 4
# Dist[F] = 15<br>
# + Current Distance of E > (Distance of C ) + (Weight of C to E) i.e. Infinity > 10 + 3
# Dist[E] = 13
#
# | A  | B  | C  | D  | E  | F  |
# | -- | -- | -- | -- | -- | -- |
# | 0  |  7  |  10  |  11  |  13  |  15  |
#
# Step 5: During 4th Relaxation:<br>
# + Current Distance of D > (Distance of E) + (Weight of E to D) i.e. 11 > 13 + (-3)
# Dist[D] = 10<br>
# + Current Distance of E > (Distance of F ) + (Weight of F to E) i.e. 13 > 15 + (-5)
# Dist[E] = 10
#
# | A  | B  | C  | D  | E  | F  |
# | -- | -- | -- | -- | -- | -- |
# | 0  |  7  |  10  |  10  |  10  |  15  |
#
# Step 6: During 5th Relaxation:
#
# + Current Distance of F > (Distance of D) + (Weight of D to F) i.e. 15 > 10 + 4
# Dist[F] = 14<br>
# + Current Distance of D > (Distance of E ) + (Weight of E to D) i.e. 10 > 10 + (-3)
# Dist[D] = 7
#
# | A  | B  | C  | D  | E  | F  |
# | -- | -- | -- | -- | -- | -- |
# | 0  |  7  |  10  |  7  |  10  |  14  |
#
# + Since the graph h 6 vertices, So during the 5th relaxation the shortest distance for all the vertices should have been calculated.
#
# Step 7: Now the final relaxation i.e. the 6th relaxation should indicate the presence of negative cycle if there is any changes in the distance array of 5th relaxation.
#
# During the 6th relaxation, following changes can be seen:
#
# + Current Distance of E > (Distance of F) + (Weight of F to E) i.e. 10 > 14 + (-5)
# Dist[E]=9<br>
# Current Distance of F > (Distance of D ) + (Weight of D to F) i.e. 14 > 7 + 4
# Dist[F]=11<br>
# Since, we observe changes in the Distance array Hence ,we can conclude the presence of a negative cycle in the graph.
#
# | A  | B  | C  | D  | E  | F  |
# | -- | -- | -- | -- | -- | -- |
# | 0  |  7  |  10  |  7  |  9  |  11  |
#
# Result: A negative cycle (D->F->E) exists in the graph.
#
# + If the graph contains a negative-weight cycle, you cannot use the Bellman-Ford algorithm to reliably find a single shortest path. The Bellman-Ford algorithm is primarily designed to find the shortest paths in graphs with weighted edges, and it can also detect the presence of negative-weight cycles. However, it is not designed to find a unique shortest path in graphs with negative-weight cycles.
#
# Algorithm to Find Single Shortest Path using Bellman-Ford
#
# + Step 1: Initialize distances from src to all other vertices as INFINITE<br>
# + Step 2: Relax all edges |V| - 1 times. A simple shortest path from src to any other vertex can have at-most |V| - 1 edges<br>
# + Step 3: check for negative-weight cycles. The above step guarantees shortest distances if graph doesn't contain negative weight cycle. If we get a shorter path, then there is a cycle.

# %%
class Graph:
 
    def __init__(self, vertices):
        self.V = vertices  # No. of vertices
        self.graph = []
 
    # function to add an edge to graph
    def addEdge(self, u, v, w):
        self.graph.append([u, v, w])
 
    # utility function used to print the solution
    def printArr(self, dist):
        print("Vertex Distance from Source")
        for i in range(self.V):
            print("{0}\t\t{1}".format(i, dist[i]))
 
    # The main function that finds shortest distances from src to
    # all other vertices using Bellman-Ford algorithm. The function
    # also detects negative weight cycle
    def BellmanFord(self, src):
 
        # Step 1: Initialize distances from src to all other vertices
        # as INFINITE
        dist = [float("Inf")] * self.V
        dist[src] = 0
 
        # Step 2: Relax all edges |V| - 1 times. A simple shortest
        # path from src to any other vertex can have at-most |V| - 1
        # edges
        for _ in range(self.V - 1):
            # Update dist value and parent index of the adjacent vertices of
            # the picked vertex. Consider only those vertices which are still in
            # queue
            for u, v, w in self.graph:
                if dist[u] != float("Inf") and dist[u] + w < dist[v]:
                    dist[v] = dist[u] + w
 
        # Step 3: check for negative-weight cycles. The above step
        # guarantees shortest distances if graph doesn't contain
        # negative weight cycle. If we get a shorter path, then there
        # is a cycle.
 
        for u, v, w in self.graph:
            if dist[u] != float("Inf") and dist[u] + w < dist[v]:
                print("Graph contains negative weight cycle")
                return
 
        # print all distance
        self.printArr(dist)
 
 
# Driver's code
if __name__ == '__main__':
    g = Graph(7)
    g.addEdge(0, 1, 7)
    g.addEdge(1, 2, 3)
    g.addEdge(1, 3, 4)
    g.addEdge(3, 5, 3)
    g.addEdge(5, 4, -3)
    g.addEdge(4, 6, 4)
    g.addEdge(6, 5, -5)
 
    # function call
    g.BellmanFord(0)
# Out:
# Graph contains negative weight cycle

# %% [markdown]
# **Reflection Quality:**
# + I used chatGPT to create a question.
# + To better understand the concept of the Bellman-Ford Algorithm, I used Google to research and gather information.
# + Initially, I found myself pondering the question of why we need the Bellman-Ford Algorithm when Dijkstra's Algorithm seems capable of solving similar problems.
# + Through my research, I discovered that the Bellman-Ford Algorithm has a unique advantage: it can handle graphs with negative edge weights, a feature that Dijkstra's Algorithm lacks.
# + This learning experience provided me with a deeper understanding of the Bellman-Ford Algorithm, which I have documented in my readme file for future reference.

# %% [markdown]
# **Question3**<br>
# Use the Ford-Fulkerson algorithm to find the maximum flow from node 1 to 7 in the weighted directed graph below. Show your work.
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ques3.png?raw=true)

# %% [markdown]
# ***Solution:***
#
# Lets Solve the above problem. Here, our source will be 1 as it has all outward edges and no inward edges and our sink will be 7 as it has all inward edges and no outward edges.
#
# 1. Initialization:
#
# + Set the maximum flow to 0.
# + Start with an initial feasible flow (can be zero initially).
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans3_01.png?raw=true)
#
# 2. Augmenting Paths:
#
# + Find an augmenting path from 1 to 7 using techniques like Breadth-First Search (BFS) or Depth-First Search (DFS).
# + We will take path 1->2->5->7
#
# 3. Capacity of the Path:
#
# Determine the maximum flow that can be pushed along this path, which is the minimum capacity of the edges on the path. For example, if the path is 1 -> 2 -> 5 -> 7, the minimum capacity is 5.
#
# 4. Update the Flow:
#
# + Increase the flow along the path by the capacity found in step 3. This increases the maximum flow.
#
# 5. Update Residual Graph:
#
# + Update the residual capacities of the edges to reflect the flow added in step 4. The residual capacity of an edge is the original capacity minus the flow.
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans3_02.png?raw=true)
#
# So, we get flow = 5
#
# 6. Repeat Steps 2-5:
#
# Continue to find augmenting paths, update flow, and residual graph until no more augmenting paths can be found.
#
# For augmented path 1 -> 3 -> 6 -> 7
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans3_03.png?raw=true)
#
# So, we get flow = 5 + 4
#
# For augmented path 1 -> 2 -> 4 -> 5 -> 7
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans3_04.png?raw=true)
#
# So, we get flow = 5 + 4 + 2
#
# For augmented path 1 -> 3 -> 4 -> 5 -> 7
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans3_05.png?raw=true)
#
# So, we get flow = 5 + 4 + 2 + 1
#
# Maximum Flow:
#
# 5 + 4 + 2 + 1 = 12
#
# **Reflection Quality:**
# + I used ChatGPT to create question.
# + I then used Google to clear my concept on Ford-Fulkerson algorithm which I have included in readme file.

# %% [markdown]
# **Question4**<br>
# Use the Preflow-Push (Push–relabel) maximum flow algorithm to find the maximum flow from node A to E in the weighted directed graph below. Show your work.
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ques4.png?raw=true)

# %% [markdown]
# ***Solution***
#
# 1. Initialize<br>
# + s has h=6 i.e. number of nodes<br>
# + Push 10 along (s,a). e(a) = 10<br>
# + Push 12 along (s,c). e(c) = 12<br>
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans4_01.png?raw=true)
#
# 2. Make c the Active Node<br>
# + Relabel c with h=1. push 6 along (c,d). e(d) = 6<br>
# + Push 5 along (c,a). e(a) = 15<br>
# + Relabel c with h=7. push -1 along (s,c).
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans4_02.png?raw=true)
#
# 3. Make a the Active Node<br>
# + Relabel a with h=1. push 15 along (a,b). e(b) = 15
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans4_03.png?raw=true)
#
# 4. Make b the Active Node<br>
# + Relabel b with h=1. push 3 along (b,t). e(t) = 3<br>
# + Push 8 along (b,d). e(d) = 14<br>
# + Relabel b with h=2. push -4 along (a,b).e(a) = 4
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans4_04.png?raw=true)
#
# 5. Make d the Active Node<br>
# + Relabel d with h=1. push 14 along (d,t). e(t) = 17
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans4_05.png?raw=true)
#
# 6. Make a the Active Node<br>
# + Repeat the process until we get h=7 at a.
# + Relabel a with h=7. push -4 along (s,a). e(a) = 0
#
# ![Imgur](https://github.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/blob/Students/Submissions/002786959_Yuktaba_Gohil/images/Assign3_Ans4_06.png?raw=true)
#
# So the maximum flow we get here is 17.
#
# I have also attached the algorithm code with test case same as the question

# %%
class Edge: 
     
    def __init__(self, flow, capacity, u, v):
        self.flow = flow
        self.capacity = capacity
        self.u = u
        self.v = v
 
# Represent a Vertex 
class Vertex:
   
    def __init__(self, h, e_flow):
        self.h = h
        self.e_flow = e_flow
 
         
# To represent a flow network 
class Graph:
     
    # int V;    # No. of vertices 
    # vector<Vertex> ver; 
    # vector<Edge> edge; 
    def __init__(self, V):
         
        self.V = V; 
        self.edge = []
        self.ver = []
        # all vertices are initialized with 0 height 
        # and 0 excess flow 
        for i in range(V):
            self.ver.append(Vertex(0, 0))
     
    def addEdge(self, u, v, capacity):
        # flow is initialized with 0 for all edge 
        self.edge.append(Edge(0, capacity, u, v))
 
 
    def preflow(self, s):
         
        # Making h of source Vertex equal to no. of vertices 
        # Height of other vertices is 0. 
        self.ver[s].h = len(self.ver); 
 
        for i in range(len(self.edge)): 
             
            # If current edge goes from source 
            if (self.edge[i].u == s):
                # Flow is equal to capacity 
                self.edge[i].flow = self.edge[i].capacity
 
                # Initialize excess flow for adjacent v 
                self.ver[self.edge[i].v].e_flow += self.edge[i].flow
 
                # Add an edge from v to s in residual graph with 
                # capacity equal to 0 
                self.edge.append(Edge(-self.edge[i].flow, 0, self.edge[i].v, s))
                 
 
    # returns index of overflowing Vertex 
    def overFlowVertex(self):
         
        for i in range(1, len(self.ver)-1): 
             
            if(self.ver[i].e_flow > 0):
                return i
 
        # -1 if no overflowing Vertex 
        return -1
     
 
    # Update reverse flow for flow added on ith Edge 
    def updateReverseEdgeFlow(self, i, flow):
         
        u = self.edge[i].v
        v = self.edge[i].u 
 
        for j in range(0, len(self.edge)): 
            if (self.edge[j].v == v and self.edge[j].u == u):
                self.edge[j].flow -= flow
                return
 
        # adding reverse Edge in residual graph 
        e = Edge(0, flow, u, v)
        self.edge.append(e)
         
 
    # To push flow from overflowing vertex u 
    def push(self, u): 
         
        # Traverse through all edges to find an adjacent (of u) 
        # to which flow can be pushed 
        for i in range(0, len(self.edge)): 
             
            # Checks u of current edge is same as given 
            # overflowing vertex 
            if (self.edge[i].u == u):
                # if flow is equal to capacity then no push 
                # is possible 
                if (self.edge[i].flow == self.edge[i].capacity):
                    continue; 
 
                # Push is only possible if height of adjacent 
                # is smaller than height of overflowing vertex 
                if (self.ver[u].h > self.ver[self.edge[i].v].h):
                     
                    # Flow to be pushed is equal to minimum of 
                    # remaining flow on edge and excess flow. 
                    flow = min(self.edge[i].capacity - self.edge[i].flow, self.ver[u].e_flow)
 
                    # Reduce excess flow for overflowing vertex 
                    self.ver[u].e_flow -= flow; 
 
                    # Increase excess flow for adjacent 
                    self.ver[self.edge[i].v].e_flow += flow; 
 
                    # Add residual flow (With capacity 0 and negative 
                    # flow) 
                    self.edge[i].flow += flow; 
 
                    self.updateReverseEdgeFlow(i, flow); 
 
                    return True; 
 
        return False;  
     
     
    # function to relabel vertex u 
    def relabel(self, u):
        # Initialize minimum height of an adjacent 
        mh = 2100000
 
        # Find the adjacent with minimum height 
        for i in range(len(self.edge)):  
            if (self.edge[i].u == u):
                 
                # if flow is equal to capacity then no 
                # relabeling 
                if (self.edge[i].flow == self.edge[i].capacity):
                    continue; 
 
                # Update minimum height 
                if (self.ver[self.edge[i].v].h < mh):
                    mh = self.ver[self.edge[i].v].h; 
 
                    # updating height of u 
                    self.ver[u].h = mh + 1; 
 
     
    # main function for printing maximum flow of graph 
    def getMaxFlow(self, s, t):
         
        self.preflow(s); 
 
        # loop until none of the Vertex is in overflow 
        while (self.overFlowVertex() != -1):
             
            u = self.overFlowVertex(); 
            if (self.push(u) == False):
                self.relabel(u); 
 
        # ver.back() returns last Vertex, whose 
        # e_flow will be final maximum flow 
        return self.ver[len(self.ver)-1].e_flow
 
     
# Driver program to test above functions 
V = 6; 
g = Graph(V);
 
# Creating above shown flow network 
g.addEdge(0, 1, 10); 
g.addEdge(0, 3, 12); 
g.addEdge(1, 2, 15); 
g.addEdge(3, 1, 5); 
g.addEdge(3, 4, 6); 
g.addEdge(2, 4, 8); 
g.addEdge(2, 5, 3); 
g.addEdge(4, 5, 17); 

# Initialize source and sink 
s = 0
t = 5; 
 
print("Maximum flow is ",  g.getMaxFlow(s, t));
# Out:
# Maximum flow is  17

# %% [markdown]
# **Reflection Quality**
#
# + I used ChatGPT to frame the question.<br>
# + Further, I used google and watched some youtube videos to clear my concept of push relabel algortihm which I have included in readme file.

# %% [markdown]
# **Question5**<br>
# **You are tasked with managing a flow network with unit capacity edges represented as a directed graph G = (V, E). The network consists of a source vertex s ∈ V and a target/sink vertex t ∈ V. Each edge e ∈ E has a cost ce associated with it, where ce ≥ 0. Given an integer parameter k (where k ≤ |E|), your goal is to optimize the network.**
#
# **In this scenario, your objective is to maximize the flow from s to t while ensuring that the total cost of the selected edges does not exceed a given budget B. You are allowed to remove up to k edges from the network, and you aim to select the optimal set of edges M ⊆ E with a cardinality of k (|M| = k, and M is a subset of E) such that you achieve the highest possible flow from s to t while staying within the budget.**
#
# **Design a polynomial-time algorithm that identifies the optimal subset of edges M to remove, with the goal of maximizing the flow from s to t, subject to the budget constraint and edge deletion limit. Your algorithm should be efficient and capable of finding the best solution within a polynomial time frame.**

# %% [markdown]
# ***Solution:***
#
# To solve this problem, lets use a well-known algorithm called the Minimum Cost Max Flow (MCMF) algorithm. This algorithm helps us find the best combination of edges to maximize flow while staying within a budget.
#
# Here's a simplified step-by-step explanation of how the algorithm works:
#
# 1. Set Up the Network:
#
# + First, we represent our network as a graph with nodes and edges. Each edge has a cost associated with it.
# + We identify the source node (s) and the sink node (t) in the network.
#
# 2. Start with an Initial Flow:
#
# + We begin with an initial flow in the network. This flow represents how much stuff (like water, data, or goods) can travel from the source to the sink.
# Iterate to Improve Flow:
#
# 3. We repeat the following steps to improve the flow while respecting the budget and edge deletion limit:
# a. Find a Path:
#
# + We search for a path from the source (s) to the sink (t) in the network. This path represents the route we can use to send more stuff.
#
# b. Determine Flow on the Path:
#
# + We calculate how much stuff (flow) we can send along this path without exceeding our budget.
#
# c. Update Flow and Cost:
#
# + We increase the flow along the path, which means we send more stuff.
# + We also update the cost of using this path. We want to minimize the total cost while maximizing the flow.
#
# d. Repeat Until No More Paths:
#
# + We keep finding paths and sending more stuff as long as there are more paths to consider.
#
# 4. Limit Edge Deletions:
#
# + To stay within the edge deletion limit (k), we can consider removing edges with the highest cost but only if it doesn't harm the flow too much.
#
# 5. Optimal Solution:
#
# + Once we've gone through all the steps, we've found the best combination of edges to maximize the flow while keeping the cost within the budget and not exceeding the edge deletion limit.
#
# **Relevance to the Sample Problem**
#
# The two questions involve flow networks and edge deletion but have opposing optimization goals: flow maximization with cost constraints in the question given by me and flow minimization in the sample question.
#
# 1. The question I provided focuses on optimizing a flow network by maximizing the flow from source to sink while adhering to a budget constraint and a limit on the number of edges that can be removed (k). This problem deals with flow maximization within cost constraints.
#
# 2. The sample question deals with the optimization of a flow network by minimizing the flow capacity from the source to the sink. The objective is to remove k edges from the network to reduce the flow capacity as much as possible.
#
# **Reflection Quality**
#
# + I created the question with the help of ChatGPT.
# + Further, I used GPT here to clear my concepts related to this question.
# + What I found particularly helpful was the concept of a Minimum Cost Max Flow (MCMF) algorithm, which is used to optimize the network.This algorithm enables us to find the best combination of edges to maximize the flow while respecting budget constraints.

# %% [markdown]
# **Question6**<br>
# **Consider a scenario in which paramedics are responding to a major disaster, such as a wildfire, and need to evacuate a region. There are n people distributed across the area who need to be moved to safety. There are k evacuation centers in the region, and each person must be transported to a center within a certain time frame for safety. The challenge is to distribute the evacuees to the centers in a way that avoids overloading any of them.**
#
# **Design a polynomial-time algorithm to determine whether it is possible to assign each person to an evacuation center while ensuring that no center receives more than [n/k] people. The algorithm should take into account the locations of the people, the capacity of the evacuation centers, and the time constraints.**

# %% [markdown]
# ***Solution:***
#
# To solve the problem of distributing evacuees to evacuation centers while ensuring that no center receives more than [n/k] people, we can use a polynomial-time algorithm. The algorithm can be structured as follows:
#
# Algorithm: Distributing Evacuees to Centers
#
# + Initialize a flow network with nodes representing evacuees, evacuation centers, and a source and sink.
#
# + Create an edge from the source to each evacuee with a capacity of 1, representing that each evacuee can be assigned to one center.
#
# + Create an edge from each evacuee to each evacuation center with a capacity of 1, representing the possibility of assignment.
#
# + Create an edge from each evacuation center to the sink with a capacity of [n/k], representing the limit on the number of people each center can accommodate.
#
# + Apply the Ford-Fulkerson algorithm or any polynomial-time max-flow algorithm to find the maximum flow in the network.
#
# + If the maximum flow is equal to n (the number of evacuees), it means that it's possible to assign each person to an evacuation center while ensuring that no center receives more than [n/k] people. Return "Possible."
#
# + If the maximum flow is less than n, it's not possible to distribute all evacuees while respecting the constraints. Return "Not Possible."
#
# Explanation:
#
# This algorithm creates a flow network in which each evacuee is connected to each evacuation center. The maximum flow in this network represents the number of evacuees that can be successfully assigned to centers without overloading any of them.
#
# If the maximum flow equals n, it means it's possible to distribute all evacuees while ensuring that no center receives more than [n/k] people. If the maximum flow is less than n, it's not possible to meet the constraints.
#
# The algorithm runs in polynomial time, making it an efficient way to determine the feasibility of distributing evacuees to centers while maintaining balance and respecting the specified constraints.
#
# This algorithm can be applied to real-world scenarios where resource allocation during crises, such as natural disasters, is critical for saving lives and ensuring the efficient use of evacuation centers.
#
# **Relevance to the Sample Problem**
#
# + The sample problem presented a network flow problem in the context of distributing injured individuals to hospitals during a crisis. The challenge was to allocate individuals to hospitals while avoiding overloading any single hospital. This problem required finding a balanced assignment of individuals to hospitals.
#
# + The problem created by me is relevant to the original problem as it also involves allocating individuals to facilities (evacuation centers) during a disaster, with the added constraint of time sensitivity.
#
# **Reflection Quality**
#
# + I used ChatGPT to create a question and brainstorming potential algorithmic solutions.
# + The algorithm I designed is based on flow network principles, where we represent individuals and centers as nodes and allocate capacities through edges.
# + This approach helps in structuring and solving such problems efficiently.

# %% [markdown]
# **Question7**<br>
# **You are tasked with planning the expansion of a popular retail store along a street with N blocks. On each block, there is a potential location for a store, and opening a store on block i will yield a profit of pi, where pi > 0. However, there is a condition: no two adjacent blocks can have open stores.**
#
# **Your goal is to determine the subset of locations on which to open stores to maximize the total profit, given the adjacency constraint.**
#
# **1. Define the Sub Problems**
#
# **2. Present Your Recurrence**
#
# **3. Prove Your Recurrence is Correct**
#
# **4. State and Prove Base Cases**

# %% [markdown]
# ***Solution:***
#
# 1. Define the Sub Problems<br>
# Let OPT(i) be the maximum profit achievable from opening stores on blocks 1 to i.
#
# 2. Present Your Recurrence<br>
# `OPT(i)` can be expressed as:
#
# `OPT(i) = max(OPT(i-2) + pi, OPT(i-1))`
#
# In other words, the maximum profit at block i is the maximum of two options:
#
# + If you open a store at block i, you add the profit pi to the profit of the best solution for block i-2.
# + If you skip block i and move to the next, you take the profit from the best solution for block i-1.
#
# 3. Prove Your Recurrence is Correct<br>
# We can prove the correctness of the recurrence as follows:
#
# + If we choose to open a store at block i, we add the profit pi to the maximum profit achievable up to block i-2, which follows the adjacency constraint (i and i-1 cannot be both open). This guarantees that the solution is valid.
#
# + If we choose to skip block i, we consider the maximum profit achievable up to block i-1, which satisfies the adjacency constraint as well.
#
# Since we are comparing both options and selecting the one that yields higher profit, the recurrence accurately represents the optimal solution.
#
# 4. State and Prove Base Cases<br>
# + The base case is OPT(1) = p1 (if you open a store on the first block, the profit is p1).
#
# + For OPT(2), we have two options: open a store on block 1 or block 2, but not both. We choose the one with the higher profit, which is max(p1, p2).
# Relevance to the Original Problem:
#
# **Relevance to the Sample Problem**
#
# The problem I created shares a similar structure and concept with the sample problem you provided. In both scenarios, the objective is to maximize profit while adhering to specific constraints. The recurrence relation and dynamic programming approach used to solve the two problems are closely related.
#
# **Reflection Quality**
#
# + I used ChatGPT to create a similar question.<br>
# + ChatGPT helped me to explore algorithmic concepts. The problem highlighted the importance of breaking down complex problems into smaller, solvable parts. The recurrence relation I created is a fundamental concept in dynamic programming, and it showed how this technique can be applied to various scenarios.

# %% [markdown]
# **Question8**<br>
# **For each of the following recurrences, give an expression for the runtime T(n) if the recurrence can be solved with the Master Theorem. Otherwise, indicate that the Master Theorem does not apply.**
#
# **i. T(n) = 4T(n/2) + cn<br>**
# **ii. T(n) = T(n/2) + 2n<br>**
# **iii. T(n) = (6<sup>n</sup>)T(n/2) + n<br>**
# **iv. T(n) = 4T(n/4) + nlog(n)<br>**
# **v. T(n) = 0.7T(n/2) + 1/n**

# %% [markdown]
# ***Solution:***
#
# i. T(n) = 4T(n/2) + cn
#
# For this recurrence, we can use the Master Theorem. It has the form:
#
# T(n) = aT(n/b) + f(n), where a >= 1 and b > 1.
#
# Let's solve it step by step:
#
# a. Extract a, b, and f(n):
#
# a = 4, b = 2, and f(n) = cn.
#
# b. Determine the value of n<sup>(log_b(a))</sup>:
#
# n<sup>(log_2(4))</sup> = n<sup>2</sup>.
#
# c. Compare f(n) and n<sup>(log_b(a))<sup>:
#
# f(n) = cn and n<sup>(log_b(a))</sup> = n^2.
#
# Since f(n) is a polynomial of degree 1, and n<sup>(log_b(a))</sup> is a polynomial of degree 2, we need to compare their growth rates.
#
# d. Compare the growth rates:
#
# f(n) = O(n<sup>2</sup>)
#
# Here, f(n) is dominated by n^2, which means we are in Case 1 of the Master Theorem.
#
# e. Apply the Master Theorem Case 1:
#
# T(n) = &theta;(n<sup>(log_b(a))</sup>)
#
# T(n) = &theta;(n<sup>2</sup>)
#
# So, the solution to the recurrence T(n) = 4T(n/2) + cn is T(n) = &&theta;;(n<sup>2</sup>).
#
# ii. T(n) = T(n/2) + 2n
#
# For this recurrence, we can use the Master Theorem. It has the form:
#
# T(n) = aT(n/b) + f(n), where a >= 1 and b > 1.
#
# Let's solve it step by step:
#
# a. Extract a, b, and f(n):
#
# a = 1, b = 2, and f(n) = 2n.
#
# b. Determine the value of n<sup>(log_b(a))</sup>:
#
# n<sup>(log_2(1))</sup> = n^0 = 1.
#
# c. Compare f(n) and n<sup>(log_b(a))</sup>:
#
# f(n) = 2n, and n<sup>(log_b(a))</sup> = 1.
#
# d. Compare the growth rates:
#
# f(n) = &omega;(n<sup>(log_b(a)+ε)</sup>), where ε > 0. In this case, ε = 1.
#
# Here, f(n) is greater than n^1, which means we are in Case 2 of the Master Theorem.
#
# e. Apply the Master Theorem Case 2:
#
# T(n) = &theta;(f(n))
#
# T(n) = &theta;(2n)
#
# So, the solution to the recurrence T(n) = T(n/2) + 2n is T(n) = &theta;(2n).
#
# iii. T(n) = (6<sup>n</sup>)T(n/2) + n
#
# For this recurrence, the Master Theorem does not apply because 'a' is not a constant, making it incompatible with the standard form of the Master Theorem.
#
# iv. T(n) = 4T(n/4) + n*log(n)
#
# For this recurrence, we can use the Master Theorem. It has the form:
#
# T(n) = aT(n/b) + f(n), where a >= 1 and b > 1.
#
# Let's solve it step by step:
#
# a. Extract a, b, and f(n):
#
# a = 4, b = 4, and f(n) = n*log(n).
#
# b. Determine the value of n<sup>(log_b(a))</sup>:
#
# n<sup>(log_4(4))</sup> = n.
#
# c. Compare f(n) and n^(log_b(a)):
#
# f(n) = n*log(n), and n<sup>(log_b(a))</sup> = n.
#
# d. Compare the growth rates:
#
# f(n) = &theta;(n^<sup>(log_b(a) * log(n))</sup>)
#
# In this case, f(n) is of the same order of magnitude as n*(log(n)), and the logarithmic factor is not dominating. So, we are still in Case 2 of the Master Theorem.
#
# e. Apply the Master Theorem Case 2:
#
# T(n) = &theta;(n<sup>(log_b(a))</sup> * log^(k+1)(n)), where k is 0 for Case 2.
#
# T(n) = &theta;(n * log<sup>1(n)</sup>)
#
# T(n) = &theta;(n * log(n))
#
# So, the solution to the recurrence T(n) = 4T(n/4) + n*log(n) is indeed T(n) = &theta;(n * log(n)).
#
# v. T(n) = 0.7T(n/2) + 1/n
#
# For this recurrence, the Master Theorem does not apply because 'a' is less than 1, which violates the condition for the Master Theorem to be applicable. The Master Theorem requires 'a' to be greater than or equal to 1. Therefore, we cannot use the Master Theorem to solve this recurrence.

# %% [markdown]
# **Reflection Quality**
#
# + ChatGPT helped me form a question similar to the Sample Problem. <br>
# + Further I used Google to clear my concepts related to Masters Theorem which I have included in readme file.<br>
# + As we have already used Masters Theorem in Assignment 2, it was not difficult this time.
