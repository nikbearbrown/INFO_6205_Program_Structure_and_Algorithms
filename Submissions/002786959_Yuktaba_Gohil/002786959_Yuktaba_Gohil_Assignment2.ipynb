# %% [markdown]
# #Assignment 2

# %% [markdown]
# Q1(10 Points)<br>
# Use Kruskal's Algorithm to find the MST of this graph, and the total weight of the MST. Also, determine the time complexity of your Kruskal's Algorithm implementation.
#
#     ![Graph](https://raw.githubusercontent.com/Yuktagohil/INFO_6205_Program_Structure_and_Algorithms/Students/Submissions/002786959_Yuktaba_Gohil/images/![Assign2_Ques1.png](attachment:Assign2_Ques1.png))
