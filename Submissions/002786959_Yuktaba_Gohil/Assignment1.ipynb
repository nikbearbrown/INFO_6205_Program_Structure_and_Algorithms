# %% [markdown]
# #Assignment 1

# %% [markdown]
# Q1 (10 Points) <br>
# Arrange the following functions in increasing order of growth:<br>
# • 2<sup>n<sup>2</sup></sup><br>
# • n<sup>3</sup>log<sup>2</sup>(n)<br>
# • n<sup>4</sup><br>
# • nlog(n)<br>
# • 3<sup>n</sup><br>
# • n!<br>
# • n<sup>log(n)</sup><br>
# • n<sup>5</sup><br>
# • 5<sup>n</sup><br>
# • log(n<sup>3</sup>)<br>

# %% [markdown]
# Q2 (10 Points)<br>
# Assume that you have function f and g such that f(n) is O(g(n)). For each of the following statements decide whether it is true or false and give a proof or counter example.<br>
# •	f(n)=O(f(n+1))<br>
# •	f(n)=O(f(2n))<br>
# •	f(n)=O(g(n+1))<br>
# <br>
# Solution:<br><br>
# Statement 1: f(n)=O(f(n+1))<br>
# False<br>
# This statement is saying that the function f(n) grows at the same rate or slower than the function f(n+1). This is not always true. For example, the function 2^n grows faster than the function 2^(n+1), so 2^n is not O(2^(n+1)).<br><br>
# Statement 2: f(n)=O(f(2n))<br>
# True<br>
# This statement is saying that the function f(n) grows at the same rate or slower than the function f(2n). This is always true. This is because f(2n) is just a scaled version of f(n). For example, if f(n) = n, then f(2n) = 2n. So, f(n) is O(f(2n)).<br>
# To prove this statement true, we need to show that for any function f(n) that is big-O of g(n), it is also big-O of g(2n). Let's assume that f(n) is O(g(n)).<br>
# According to the definition of big-O notation, there exist constants C and n0 such that for all n ≥ n0, f(n) ≤ C * g(n).<br>
# Now, consider f(2n). We want to show that f(2n) is also bounded by a constant multiple of g(2n). Using the definition of big-O, we need to find new constants C' and n0' such that for all n ≥ n0', f(2n) ≤ C' * g(2n).<br>
# Let's simplify this:<br>
# f(2n) ≤ C' * g(2n)<br>
# Now, we can manipulate the inequality:<br>
# f(n) ≤ C' * (g(2n) / 2)<br>
# Since (g(2n) / 2) is still a function of n, we can rewrite this as:<br>
# f(n) ≤ C'' * g(n)<br>
# where C'' = (C' / 2). Now, we have shown that f(n) is O(g(n)), and the statement is true.<br><br>
# Statement 3: f(n)=O(g(n+1))<br>
# False<br>
# Counterexample: <br>
# Suppose f(n) = n and g(n) = n. It's clear that f(n) is O(g(n)) since they are the same function.<br>
# Now, let's check if f(n) is O(g(n+1)). To do this, we need to show that there exist constants C and n0 such that for all n ≥ n0, f(n) ≤ C * g(n+1).<br>
# However, in this case, it's not possible to find such constants. Let's assume by contradiction that we can find C and n0. Then we have:<br>
# n ≤ C * (n+1)<br>
# Now, divide both sides by (n+1):<br>
# n / (n+1) ≤ C<br>
# As n approaches infinity, the left-hand side approaches 1, while C remains a constant. This is a contradiction because there's no constant C that can bound 1 as n becomes arbitrarily large.<br>
# Therefore, there are no constants C and n0 that satisfy the condition for f(n) being O(g(n+1)), and the statement is false.<br><br>
# Reflection Quality<br>
# I used ChatGPT here to understand the concept of flexibility and adaptability of big-O notation. I learnt how different functions compare in terms of their growth rates.

# %% [markdown]
# Q3 (10 Points)<br>
# Imagine you have a group of roommates living together in a shared house. Each roommate has a preference list ranking all the other roommates in order of compatibility as potential roommates.<br><br>
# Your goal is to find a stable roommate assignment, meaning that there are no pairs of roommates who would both prefer to live with each other over their current assignments.<br><br>
# Write an algorithm to find a stable roommate assignment based on their preference lists. You can assume that <br>
# a. The number of roommates is even<br>
# b. Each roommate must be assigned to exactly one other roommate.<br><br>
# The assignment of roommates to specific rooms is considered stable if neither of the following situations arises:<br>
# There are roommates R1,R2 and a room A such that:<br>
# R1 is assigned to room A,<br>
# R2 is unassigned and not assigned to any room, and<br>
# R1 prefers R2 based on their compatibility rankings.<br><br>
# There are roommates R1,R2,R3 and rooms A and B, such that:<br>
# R1 and R3 are assigned to room A,<br>
# R2 is assigned to room B,<br>
# R1 prefers R2 over R3, and<br>
# R2 prefers room A over room B.<br><br>
# This is similar to the stable matching problem.Please explain your algorithm step by step and provide a proof of its correctness.<br><br>
# Solution:<br><br>
# The problem can be solved using the "Stable Matching" algorithm, which ensures that no roommates would prefer each other over their current assignments.<br><br>
# The algorithm looks like this:<br><br>
# Initialize a list of unassigned roommates.<br>
# While there are still unassigned roommates:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Find the roommate with the highest priority on the list of unassigned roommates.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Find the roommate with the highest priority on the preference list of the first roommate.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;If the second roommate is unassigned, assign them to each other.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Otherwise, if the second roommate prefers the first roommate to their current roommate, assign them &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;to each other and update the number of available positions in the first roommate's current room.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Otherwise, the first roommate remains in their current room.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;All roommates are now assigned<br><br>
# Here's a step-by-step explanation of the algorithm:<br>
#
# Step 1: Initialization<br>
#
# Begin by having each roommate rank all other roommates according to their preferences.<br>
# Create an array to keep track of each roommate's current assignment. Initially, no one is assigned, so all entries can be set to unassigned.<br><br>
# Step 2: While There Are Unassigned Roommates<br>
#
# Select an unassigned roommate, let's call this roommate "R1."<br>
# R1 proposes to their most preferred roommate (the one they rank the highest and haven't proposed to yet). Let's call this proposed roommate "R2."<br>
# If R2 is unassigned, or if R2 prefers R1 over their current roommate (if any), they accept the proposal, and both R1 and R2 become assigned to each other.<br>
# If R2 is already assigned to someone and prefers their current roommate over R1, they reject the proposal, and R1 remains unassigned.<br>
# Repeat these steps until there are no unassigned roommates left.<br><br>
# Step 3: Result<br>
#
# Once every roommate is assigned, you'll have a stable roommate assignment.<br><br>
# Example:<br>
#
# Consider the following preference lists for four roommates:<br>
#
# Alice: Bob, Carol, Dave<br>
# Bob: Alice, Carol, Dave<br>
# Carol: Dave, Alice, Bob<br>
# Dave: Alice, Carol, Bob<br><br>
# The algorithm would proceed as follows:<br>
#
# The list of unassigned roommates is initially [Alice, Bob, Carol, Dave].<br>
# The highest-ranked roommate on Alice's preference list who is also unassigned is Bob.<br>Therefore, the algorithm assigns Alice to Bob.<br>
# The list of unassigned roommates is now [Carol, Dave].<br>
# The highest-ranked roommate on Carol's preference list who is also unassigned is Dave. <br>Therefore, the algorithm assigns Carol to Dave.<br>
# The algorithm terminates because there are no more unassigned roommates.<br><br>
# The Gale-Shapley theorem proves the correctness of this algorithm, which states that the algorithm always produces a stable matching. It guarantees that there are no pairs of roommates who would both prefer to live with each other over their current assignments.<br>
#
# The algorithm terminates because each unassigned roommate eventually becomes assigned, and it never enters an infinite loop.<br><br>
# This algorithm has a time complexity of O(n^2), where n is the number of roommates.<br><br>
# Reflection Quality:<br><br>
# The model of roommate assignments is designed to avoid conflicts and preferences, so it requires careful consideration of each roommate's preferences.<br>
# For me, Understanding the problem statement and its similarities to the Gale-Shapley algorithm was the starting point for solving this problem. <br>
# ChatGPT assisted me in creating problem statements that were clear and concise and urged me to include all the necessary details.<br>
# Also, I used chatGPT to understand the core concepts like Gale-Shapley algorithm to solve this problem.
