# %% [markdown]
# # Assignment 3
# # Algorithm Question Design with ChatGPT
#
# Name: Jhalak Surve<br>
# Date: Oct 22, 2023

# %% [markdown]
# <h4> Analysis of Sample Example Problems Provided: </h4>

# %% [markdown]
# The sample problems are like a big test that checks how well you understand different ways of solving problems using algorithms. They ask about things like how graphs work, how to break down big problems into smaller steps, how to manage the flow of data in a network, and how to figure out how long it takes to solve a problem. These questions help see how good you are at solving real-world problems with computers.
# <br><br>
# <strong>Algorithmic Concepts Covered in sample problems:</strong>
# <br><br>
# <strong>Graph Algorithms:</strong> Concepts related to graphs, vertices, edges, and their properties.<br>
# Graph traversal and search algorithms such as Depth-First Search (DFS) and Breadth-First Search (BFS).<br>
# The Bellman-Ford algorithm for finding the shortest path in weighted graphs.
# <br><br>
# <strong>Dynamic Programming:</strong> Some questions involve dynamic programming. <br>
# Solving problems by breaking them down into smaller subproblems and using their solutions to solve the larger problem.<br>
# Applying dynamic programming to optimization problems.<br>
# One relates to weighted interval scheduling and one is related to knapsack problem.
# <br><br>
# <strong>Recurrence Relations and Master Theorem:</strong> Analyzing the time complexity of algorithms, including the use of the Master Theorem for recurrence relations.
# <br><br>
# <strong>Network Flow and Flow Algorithms:</strong> Understanding flow networks, capacities, flow augmentation, and maximum flow.<br>
# The Ford-Fulkerson algorithm and the Preflow-Push (Push–relabel) algorithm for finding the maximum flow in flow networks.

# %% [markdown]
# <h4> New Algorithmic Questions based on the provided sample problems: </h4>

# %% [markdown]
# <h4>Q1. Comparing Ford-Fulkerson and Preflow-Push Algorithms for Maximum Flow (15 points)</h4>
#
# <h5> Problem Statement:</h5>
# You are given a weighted directed graph with a source node 'S' and a sink node 'T.' The goal is to find the maximum flow from 'S' to 'T' while respecting the capacity constraints on each edge. There are two algorithms commonly used for solving this problem: the Ford-Fulkerson algorithm and the Preflow-Push algorithm.
# <br><br>
# a. Explain how each of these algorithms works to find the maximum flow in a flow network. Compare and contrast their approaches and discuss scenarios where one might be preferred over the others. (10 points)
# <br><br>
# b. Additionally, provide a brief example to illustrate the application of one of these algorithms in a specific network flow problem. (5 points)
# <br><br>
# <strong>Solution:</strong>

# %% [markdown]
# Part A:
# <h5><strong>Ford-Fulkerson Algorithm:</strong></h5>
# <strong>Operation:</strong> The Ford-Fulkerson algorithm starts with an initial flow of zero and iteratively finds augmenting paths from the source 'S' to the sink 'T' in the residual graph. It augments the flow along these paths until no more augmenting paths can be found.
# <br>
# <strong>Residual Graph:</strong> The residual graph initially mirrors the original graph but adjusts as flow is pushed through. It contains the residual capacities, which may change as the flow increases.
# <br>
# <strong>Termination:</strong> The Ford-Fulkerson algorithm does not guarantee termination for graphs with real-valued capacities. In such cases, it may result in an infinite loop.
# <br>
# <strong>Integer and Real-Valued Capacities:</strong> It can handle graphs with both integer and real-valued capacities.
# <br>
# <strong>Preference:</strong> It is a flexible approach, but it may not be the most efficient option for dense graphs.
# <br>
# <h5><strong>Preflow-Push Algorithm:</h5></strong>
# <strong>Operation:</strong> The Preflow-Push algorithm maintains a "preflow" from 'S' to 'T' and then iteratively pushes flow from nodes with excess preflow to nodes with deficits, while also performing "relabel" operations to optimize the flow.
# <br>
# <strong>Efficiency:</strong> It includes the "relabel" operation to improve efficiency by adjusting the preflow and reducing the number of flow augmentations.
# <br>
# <strong>Integer and Real-Valued Capacities:</strong> The Preflow-Push algorithm handles both integer and real-valued capacities efficiently.
# <br>
# <strong>Preference:</strong> It is often preferred for dense graphs due to its faster convergence and efficient handling of various capacities.
# <br>
# <h5><strong>Comparison:</strong></h5>
# - Ford-Fulkerson is a general approach to finding maximum flow, while Preflow-Push combines the benefits of both Ford-Fulkerson and Edmonds-Karp, making it more efficient for many scenarios.
# <br>
# - Preflow-Push is often preferred for dense graphs, thanks to its faster convergence and efficient handling of various capacities.
# <br>
# - Ford-Fulkerson is a flexible approach but may not guarantee termination for graphs with real-valued capacities. It's more suitable for exploring different flow augmentation strategies.

# %% [markdown]
# Part B:
#
# <strong>Example: Ford-Fulkerson Algorithm in Network Flow </strong>
# <br><br>
# Consider a transportation network with the following characteristics:
# <br><br>
# Source 'S' with a supply of 10 units.
# <br><br>
# Sink 'T' with a demand of 10 units.
# <br><br>
# Several intermediate nodes connected by edges with capacities:
# <br><br>
# Edge from 'S' to Node A: Capacity = 4 units<br>
# Edge from Node A to Node B: Capacity = 6 units<br>
# Edge from Node A to Node C: Capacity = 5 units<br>
# Edge from Node B to 'T': Capacity = 8 units<br>
# Edge from Node C to 'T': Capacity = 7 units<br>
# <br>
# The goal is to find the maximum flow from 'S' to 'T' while respecting capacity constraints. We'll apply the Ford-Fulkerson algorithm to solve this problem:
# <br><br>
# Initialize the flow on all edges to 0.<br>
# Find an augmenting path from 'S' to 'T' in the residual graph (initially the same as the original graph).<br>
# Update the flow along the augmenting path, increasing the flow value by the smallest capacity on the path.<br>
# Update the residual graph by subtracting the flow from forward edges and adding the flow to reverse edges.<br>
# Repeat steps 2-4 until no more augmenting paths can be found.<br>
# <br>
# In this example, the Ford-Fulkerson algorithm might start by finding an augmenting path 'S -> A -> B -> T' with a minimum capacity of 4 units. The flow is updated, and the residual graph is adjusted. Then, another augmenting path 'S -> A -> C -> T' with a minimum capacity of 5 units is found and updated. The algorithm continues until no more augmenting paths can be found.
# <br><br>
# The maximum flow achieved while respecting capacity constraints in this network will be 10 units, matching the demand at 'T'. This example demonstrates how the Ford-Fulkerson algorithm can efficiently solve network flow problems by finding augmenting paths and updating flows in the graph.

# %% [markdown]
# <strong>Algorithmic Concepts being tested:</strong>
# 1. Ford-Fulkerson Algorithm<br>
# 2. Preflow-Push Algorithm:<br>

# %% [markdown]
# <h4>Q2. Flight Delay Investigation (10 Points)</h4>
#
# <h5> Problem Statement:</h5>
# You are investigating flight delays at a major airport. You have access to data on the flights, their departure times, and potential delays. Your goal is to identify the critical flights that, if delayed, would cause a cascading effect leading to maximum overall delay in the airport's flight schedule.
# <br><br>
# <strong>Input Format:</strong>
# <br><br>
# flight_data (List of Tuples): A list of flight information, where each tuple is in the format (flight_id, departure_time, potential_delay). The flight_id is a unique identifier for the flight, departure_time is the scheduled departure time, and potential_delay is the maximum potential delay in minutes.
# <br><br>
# flight_connections (List of Tuples): A list of flight connections, where each tuple is in the format (source_flight_id, target_flight_id). It represents the connection between flights where the delay of the source flight can affect the target flight.
# <br><br>
# <strong>Output Format:</strong>
# <br><br>
# critical_flights (List of Integers): A list of flight_ids representing the critical flights that, if delayed, would lead to the maximum overall delay in the airport's flight schedule.
# <br><br>
# <strong>Sample Input:</strong>
# <br>
# <br>
# flight_data = [(1, 300, 15), (2, 310, 10), (3, 320, 5), (4, 330, 8), (5, 340, 12)]<br><br>
# flight_connections = [(1, 2), (2, 3), (3, 4), (4, 5)]
# <br><br>
# <strong>Sample Output:</strong>
# <br><br>
# Critical Flights: [1, 2, 3, 4, 5]
# <br><br>
# <strong>Constraints:</strong>
# <br><br>
# 1. The departure_time is in minutes past midnight.<br>
# 2. The number of flights is at most 100.<br>
# 3. The potential_delay for each flight is a positive integer.<br>
# 4. The number of flight connections is at most 100.
# <br><br>
# <strong>Note:</strong>
# <br><br>
# In this problem, you need to use the Bellman-Ford algorithm to identify the critical flights that, if delayed, would lead to the maximum overall delay in the airport's flight schedule.
# <br><br>
# <strong>Solution/PseudoCode:</strong>

# %%
BellmanFordCriticalFlights(flight_data, flight_connections)
    Initialize distances as an array with size equal to the number of flights, initialized to infinity
    Initialize parent_flights as an array with size equal to the number of flights, initialized to None
    Initialize critical_flights as an empty list

    Set the departure_time of the first flight as time=0
    distances[0] = 0  # The first flight has no potential delay

    # Relax edges using the Bellman-Ford algorithm
    for i from 1 to number of flights - 1:
        for each flight in flight_data:
            for each connection in flight_connections:
                source_flight_id, target_flight_id = connection
                source_flight = flight_data[source_flight_id]
                target_flight = flight_data[target_flight_id

                potential_delay = source_flight.potential_delay
                if distances[source_flight_id] + potential_delay < distances[target_flight_id]:
                    distances[target_flight_id] = distances[source_flight_id] + potential_delay
                    parent_flights[target_flight_id] = source_flight_id

    # Detect negative cycles
    for each connection in flight_connections:
        source_flight_id, target_flight_id = connection
        source_flight = flight_data[source_flight_id]
        target_flight = flight_data[target_flight_id

        potential_delay = source_flight.potential_delay
        if distances[source_flight_id] + potential_delay < distances[target_flight_id]:
            # Negative cycle detected, mark critical flights
            current_flight_id = target_flight_id
            while current_flight_id is not None:
                critical_flights.append(current_flight_id)
                current_flight_id = parent_flights[current_flight_id]

    return critical_flights

# %% [markdown]
# <strong>Justification:</strong>
# <br><br>
# The solution employs the Bellman-Ford algorithm to analyze potential flight delays and determine critical flights that could lead to maximum overall delay in the airport's flight schedule. It starts by initializing arrays to track distances and parent flights, then iteratively relaxes edges considering potential delays. The algorithm detects negative cycles, signifying situations where certain flights, if delayed, would trigger a cascading effect causing significant overall delays. The critical flights are identified by backtracking through the parent flights within negative cycles. These critical flights are the ones most pivotal in affecting the airport's overall delay scenario, making them essential to address for efficient flight management.
# <br><br>
# <strong>Algorithmic Concepts being tested:</strong>
# 1. Bellman-Ford Algorithm
# 2. Graph Algorithms
# 3. Negative Cycle Detection
# 4. Dynamic Programming

# %% [markdown]
# <h4>Q3. Weighted Interval Scheduling: Optimizing Task Selection for Maximum Importance (20 points)</h4>

# %% [markdown]
# <h5> Problem Statement:</h5>
# You are the head of a software development team working on an important project with strict deadlines. The project consists of multiple tasks, each with specific start and end times and varying levels of importance (weights). Your objective is to efficiently schedule these tasks to maximize the total importance while ensuring that no two tasks overlap in time.
# <br><br>
# Part A. Given the following list of tasks for your software project, their start times, end times, and weights, outline your approach to scheduling the tasks to maximize the total importance:
# <br><br>
# Task A: Start Time 0, End Time 3, Weight 8<br>
# Task B: Start Time 1, End Time 4, Weight 10<br>
# Task C: Start Time 3, End Time 7, Weight 6<br>
# Task D: Start Time 5, End Time 8, Weight 9<br>
# Task E: Start Time 6, End Time 9, Weight 12
# <br><br>
# Part B. How would you formally define the recurrence relation for the Weighted Interval Scheduling problem?
# <br><br>
# Part C. If the start and end times of the tasks are not given in sorted order, how would you approach sorting them before applying the dynamic programming solution?
# <br><br>
# <strong>Solution:</strong>

# %% [markdown]
# Part A:
# <br><br>
# To efficiently schedule the tasks and maximize the total importance, I would employ a dynamic programming approach for the Weighted Interval Scheduling problem. Here are the steps:
# <br><br>
# Sort the tasks: I would start by sorting the tasks based on their end times in ascending order. This sorting step ensures that we work with a list of tasks in non-decreasing order of their end times.
# <br><br>
# Initialize a dynamic programming table: I would set up a table to keep track of the maximum total importance achievable up to each task's end time. The table will have entries corresponding to each task.
# <br><br>
# Dynamic Programming: I'd iterate through the sorted tasks. For each task, I'd consider two options:
# <br><br>
# - Include the task: If I include the current task, I'd find the task with the latest end time that doesn't overlap with it. This means finding the task with the largest end time that has a start time less than or equal to the current task's end time. I'd add the weight of the current task to the maximum total importance achievable up to that non-overlapping task.
# <br><br>
# - Exclude the task: Alternatively, I'd consider the maximum total importance achieved without including the current task.

# %% [markdown]
# Fill the dynamic programming table: By iteratively considering the options of including or excluding each task, I'd populate the dynamic programming table. The entry at the last task's end time will represent the maximum total importance achievable for the entire project without any overlapping tasks.
# <br><br>
# Backtracking: If necessary, I could backtrack through the dynamic programming table to determine which tasks were selected to achieve the maximum total importance.
# <br><br>
# This dynamic programming approach ensures that we can efficiently schedule the tasks to maximize the total importance while avoiding overlaps.

# %% [markdown]
# Part B:
# <br><br>
# The recurrence relation for the Weighted Interval Scheduling problem can be defined as follows:
# <br><br>
# Let OPT(i) represent the maximum total importance achievable by scheduling tasks up to and including task i.<br><br>
# If we consider task i in our schedule, we need to find the last task (task j) that doesn't overlap with task i and has the maximum end time less than or equal to the start time of task i.<br><br>
# We can then define the recurrence relation as:<br><br>
# OPT(i) = max { Weight(i) + OPT(j), OPT(i - 1) }<br><br>
# Here, Weight(i) represents the importance of task i.
# OPT(j) represents the maximum total importance achievable up to the task that doesn't overlap with task i.

# %% [markdown]
# Part C:
# <br><br>
# To approach sorting the tasks based on their start times before applying the dynamic programming solution:
# <br><br>
# Create Pairs: Create pairs of tasks where each pair contains both the task's start time and end time along with the original task index to maintain the association with the tasks. The pairs should look like (start_time, end_time, task_index).
# <br><br>
# Sorting: Use a stable sorting algorithm (like mergesort) to sort the pairs based on their start times. A stable sort preserves the relative order of equal elements, which is crucial in case of equal start times.
# <br><br>
# Apply Dynamic Programming: Once the pairs are sorted, you can apply the dynamic programming solution to find the optimal schedule, taking into account the sorted order of tasks.

# %% [markdown]
# <strong>Algorithmic Concepts being tested:</strong>
# 1. Dynamic Programming
# 2. Weighted Interval Scheduling
# 3. Recurrence Relations
# 4. Sorting Algorithms
# 5. Algorithm Design

# %% [markdown]
# <h4>Q4. Mysterious Sorting (15 points)</h4>
#
# <h5> Problem Statement:</h5>
# Alice is trying to solve a tricky sorting problem. She is given a list of integers, and her task is to sort them using a mysterious sorting algorithm she has just discovered. The algorithm works as follows:
# <br><br>
# If the list contains only one element, it is already sorted.<br>
# Otherwise, divide the list into two equal halves.<br>
# Sort the left half using the mysterious sorting algorithm.<br>
# Sort the right half using the mysterious sorting algorithm.<br>
# Merge the two sorted halves into one sorted list.<br>
# Alice is curious about the time complexity of her mysterious sorting algorithm. She believes it can be described using the Master Theorem for Divide and Conquer Recurrences. Can you help her analyze it?
# <br><br>
# Write a function mysterious_sort(arr) that takes an unsorted list of integers as input and returns the sorted list using Alice's mysterious sorting algorithm. Then, analyze the time complexity of her algorithm using the Master Theorem. Your analysis should include identifying the values of a, b, and f(n).
# <br><br>
# <strong>Input Format:</strong>
# <br><br>
# An unsorted list of integers, arr, where 1 <= n <= 10^6.
# <br><br>
# <strong>Output Format:</strong>
# <br><br>
# The sorted list obtained using the mysterious sorting algorithm.<br>
# An analysis of the time complexity using the Master Theorem.
# <br><br>
# <strong>Sample Input:</strong>
# <br>
# <br>
# arr = [12, 5, 8, 23, 14, 7, 18]<br>
# sorted_arr, time_complexity = mysterious_sort(arr)
# <br><br>
# <strong>Sample Output:</strong>
# <br><br>
# Sorted List: [5, 7, 8, 12, 14, 18, 23]<br>
# Time Complexity Analysis: O(n log n)
# <br><br>
# <strong>Constraints:</strong>
# <br>
# 1. The input list arr contains integers.<br>
# 2. 1 <= n (the number of elements in arr) <= 10^6.<br>
# 3. The integers in arr can be positive or negative and are within the range of a 32-bit signed integer.<br>
# 4. The input list may contain duplicate values.<br>
# 5. The sorting algorithm should be implemented efficiently within the specified constraints.<br>
# 6. The time complexity analysis should adhere to the Master Theorem for divide and conquer algorithms.
# <br><br>
# <strong>Solution/PseudoCode:</strong>

# %%
def mysterious_sort(arr):
    # Base case: If the list has only one element, it is already sorted.
    if len(arr) <= 1:
        return arr

    # Divide the list into two equal halves.
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    # Recursively sort the left and right halves.
    left_sorted = mysterious_sort(left_half)
    right_sorted = mysterious_sort(right_half)

    # Merge the sorted halves to create a single sorted list.
    sorted_arr = merge(left_sorted, right_sorted)
    
    return sorted_arr

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

def time_complexity_analysis(arr):
    n = len(arr)
    if n <= 1:
        return "O(1)"
    return f"O(n * log({n}))"

# Example usage:
arr = [12, 5, 8, 23, 14, 7, 18]
sorted_arr = mysterious_sort(arr)
time_complexity = time_complexity_analysis(arr)
print("Sorted List:", sorted_arr)
print("Time Complexity Analysis:", time_complexity)
# Out:
# Sorted List: [5, 7, 8, 12, 14, 18, 23]
# Time Complexity Analysis: O(n * log(7))

# %% [markdown]
# <strong>Justification:</strong>
# <br><br>
# The solution addresses the "Mysterious Sorting" problem by employing a divide-and-conquer approach. It recursively splits the input list into smaller halves until it reaches individual elements, which are inherently sorted. Then, it merges these sorted sublists while ensuring the overall merged list remains sorted. This divide-and-conquer strategy leverages the Master Theorem to estimate the time complexity. The approach guarantees a sorted output while efficiently breaking down the problem into smaller, manageable segments. It exhibits a time complexity of O(n * log(n)), making it an effective method for sorting large datasets.
# <br><br>
# <strong>Algorithmic Concepts being tested:</strong>
# 1. Divide and Conquer
# 2. Recursion
# 3. Time Complexity Analysis and The Master Theorem
# 4. Merge Sort

# %% [markdown]
# <h4>Q5. Knapsack Algorithm Fundamentals (20 points)</h4>
#
# <h5> Problem Statement:</h5>
# You are preparing for a hiking trip, and you have a limited weight capacity for your backpack. You have a list of items with their weights and values. Your goal is to maximize the total value of items you can carry without exceeding the weight limit. Let's solve this problem step by step.
# <br><br>
# Part A. What is the name of the algorithm commonly used to solve this type of problem, where you need to maximize the value of items within a weight constraint?
# <br><br>
# Part B. In the Knapsack problem, what is the primary constraint you need to consider when selecting items to carry in your backpack?
# <br><br>
# Part C. In the Knapsack problem, each item has two associated values. What are these values, and how are they used in the algorithm?
# <br><br>
# Part D. Can you briefly explain how the Knapsack algorithm works to find the optimal solution?
# <br><br>
# Part E. If you have a list of items with weights and values and a specified weight capacity for your backpack, how can you use the Knapsack algorithm to find the maximum total value of items you can carry?
# <br><br>
# <strong>Solution:</strong>

# %% [markdown]
# Part A:
# <br><br>
# The algorithm commonly used for this problem is the "Knapsack algorithm."
# <br><br>
# Part B:
# <br><br>
# The primary constraint in the Knapsack problem is the weight capacity of the backpack. You need to ensure that the total weight of the selected items does not exceed this capacity.
# <br><br>
# Part C.
# <br><br>
# Each item in the Knapsack problem has two associated values: weight and value. The weight represents how heavy the item is, and the value represents how valuable the item is. The algorithm uses these values to determine which items to select while staying within the weight constraint and maximizing the total value.
# <br><br>
# Part D:
# <br><br>
# The Knapsack algorithm typically employs dynamic programming. It creates a table where each cell corresponds to a specific combination of items and weight capacity. The algorithm iteratively considers whether it's beneficial to include an item or not, based on the item's weight and value, while ensuring that the weight constraint is not exceeded. The final cell in the table holds the optimal solution, representing the maximum value that can be achieved within the weight limit.
# <br><br>
# Part E:
# <br><br>
# To find the maximum total value of items you can carry, you can apply the Knapsack algorithm as follows:
# <br><br>
# Create a table with rows representing items and columns representing weight capacities (from 0 to the maximum backpack capacity).
# <br><br>
# Initialize the table with zeros.
# <br><br>
# Iterate through the items and weight capacities. For each combination, determine whether it's more beneficial to include the current item or exclude it. Update the table accordingly.
# <br><br>
# The final cell of the table will contain the maximum total value achievable within the weight limit.
# <br><br>
# You can trace back through the table to identify which items were selected to achieve the maximum value.
# <br><br>
# This approach ensures that you select the optimal combination of items to carry in your backpack while respecting the weight constraint.

# %% [markdown]
# <h4>Q6. Optimizing Goods Distribution with Preflow-Push Algorithm (20 points)</h4>
# <h5> Problem Statement:</h5>
# You are tasked with optimizing the transportation of goods from a manufacturing facility (S) to multiple distribution centers (D1, D2, D3, ... Dn) using a network of routes. Each route between the manufacturing facility and a distribution center has a maximum capacity for transporting goods. Your goal is to find the maximum flow of goods from the manufacturing facility to the distribution centers while respecting the capacity constraints on each route.
# <br><br>
# Given the following information:
# <br><br>
# The capacity of each route (edge) between the manufacturing facility (S) and each distribution center (D1, D2, D3, ... Dn).<br>
# The demand (amount of goods to be transported) at each distribution center.<br>
# The flow can only move from the manufacturing facility (S) to the distribution centers (D1, D2, D3, ... Dn).
# <br><br>
# Your task is to:
# <br><br>
# a. Determine the maximum flow of goods that can be transported from the manufacturing facility (S) to all the distribution centers while respecting the capacity constraints on each route.
# <br><br>
# b. Provide a detailed plan or algorithm for finding this maximum flow. Describe the key steps involved in your plan.
# <br><br>
# c. If there is a scenario where all distribution centers cannot receive their demanded goods due to capacity limitations, explain how you would allocate the available goods to the distribution centers to maximize the total transported amount.
# <br><br>
# d. Provide an illustrative example with values for capacities, demands, and routes between the manufacturing facility and distribution centers to demonstrate your algorithm. Calculate the maximum flow for this example.
# <br><br>
# Note: You can assume that the network is represented as a directed graph with nodes (S, D1, D2, D3, ... Dn) and edges representing routes with their respective capacities.
# <br><br>
# Please solve the problem and provide your algorithm, calculations, and explanations.
# <br><br>
# <strong>Solution:</strong>

# %% [markdown]
# Part A:
# <br><br>
# The maximum flow of goods that can be transported from the manufacturing facility (S) to all the distribution centers while respecting the capacity constraints on each route is calculated using the Preflow-Push algorithm.
# <br><br>
# Part B:
# <br><br>
# Algorithm Plan:
# <br><br>
# - Initialize preflow on each edge to zero, and set the preflow excess on node S to the total supply and demand imbalance (if any) at S and the total demand at all distribution centers.<br>
# -  Create a queue to manage the nodes (vertices) with excess preflow.<br>
# - Push excess preflow from the manufacturing facility (S) to its neighboring nodes (distribution centers) until there is no more outgoing capacity or until the demand is met.<br>
# - Relabel nodes in the network to maintain a valid preflow. Relabeling increases the distance label of a node.<br>
# - Repeat steps 3 and 4 until there are no nodes with excess preflow in the queue.<br>
# - Once all excess preflow has been pushed to distribution centers, the preflow on each route represents the maximum flow in the network.

# %% [markdown]
# Part C:
# <br><br>
# Allocation Strategy:
# <br><br>
# If there is a scenario where all distribution centers cannot receive their demanded goods due to capacity limitations, you can allocate the available goods to the distribution centers based on their demands proportionally. This ensures a fair distribution, and no distribution center receives more than its capacity allows.
# <br><br>
# Part D:
# <br><br>
# Example:
# <br><br>
# Let's consider an example with the following data:
# <br><br>
# Capacity of route S to D1: 5 units<br>
# Capacity of route S to D2: 8 units<br>
# Capacity of route S to D3: 6 units<br><br>
# Demand at D1: 4 units<br>
# Demand at D2: 7 units<br>
# Demand at D3: 6 units
# <br><br>
# Step 1: Initialize preflow on each edge to zero and set the preflow excess on node S to the total supply and demand imbalance, which is 4 (total demand at D1) + 7 (total demand at D2) + 6 (total demand at D3) = 17 units.
# <br><br>
# Step 2: Create a queue for managing nodes with excess preflow.
# <br><br>
# Step 3: Push excess preflow from S to its neighboring nodes. Initially, we can push 17 units to D1 because it has the highest demand. The remaining excess preflow is 17 - 4 = 13 units.
# <br><br>
# Step 4: Relabel nodes. In this step, we can relabel the nodes to maintain a valid preflow.
# <br><br>
# Step 5: Repeat steps 3 and 4 as long as there are nodes with excess preflow. In the next iteration, we can push 8 units to D2 because it has the highest demand. The remaining excess preflow is 13 - 7 = 6 units.
# <br><br>
# Step 4: Relabel nodes again to maintain a valid preflow.
# <br><br>
# Step 5: In the final iteration, we can push 6 units to D3.
# <br><br>
# The final preflow allocation would be as follows:
# <br><br>
# Excess preflow at S: 0 units<br>
# Preﬂow on route S to D1: 4 units<br>
# Preﬂow on route S to D2: 7 units<br>
# Preﬂow on route S to D3: 6 units<br>
# This allocation respects the capacity constraints and meets the demands of the distribution centers.
# <br><br>
# The Preflow-Push algorithm ensures that capacity constraints are not violated, and the most goods are transported to meet demands, similar to the Ford-Fulkerson algorithm.

# %% [markdown]
# <strong>Algorithmic Concepts being tested:</strong>
# 1. Network Flow and Flow Algorithms (Preflow-Push Algorithm).
# 2. Handling capacity constraints.
# 3. Optimally allocating resources to meet demands.

# %% [markdown]
# # Reflection

# %% [markdown]
# <strong>Learning from Sample Problems:</strong>
# <br><br>
# - The sample problems offered a comprehensive test of my algorithmic knowledge and problem-solving skills.
# - They covered a wide range of algorithmic concepts, including graph algorithms, dynamic programming, recurrence relations, and network flow.
# <br><br>
# <strong>Assistance from ChatGPT:</strong>
# <br><br>
# - ChatGPT was instrumental in generating new algorithmic problems based on the concepts I provided.
# - It efficiently generated problem statements, saving a substantial amount of time in problem design.
# <br><br>
# <strong>Learning Beyond Samples:</strong>
# <br><br>
# Exploring Resources: I didn't stop at the sample problems. I explored external resources like algorithm websites and YouTube tutorials recommended by professor.
# <br><br>
# Deepening Understanding: These resources gave me in-depth insights into algorithms. They explained concepts thoroughly and showed practical uses. This expanded my thinking, helping me create problems that challenged students to use algorithms in real-life situations.
# <br><br>
# <strong>Challenges Faced:</strong>
# <br><br>
# - The primary challenge was striking the right balance between problem complexity and clarity. It was crucial to create problems that were challenging but not overly complicated.
# - Ensuring the uniqueness of the new problems while maintaining the essence of the example problems was a challenge.
# <br><br>
# <strong>Problem Design Insights:</strong>
# <br><br>
# - Designing algorithmic problems requires a delicate balance. Problems should be complex enough to challenge solvers, but clear and well-structured enough to guide them effectively.
# - Problem design is a blend of creativity and precision. It involves crafting scenarios that not only test algorithmic concepts but also provide clear instructions and expected results.
# <br><br>
# In summary, the sample problems deepened my understanding of various algorithmic concepts, and ChatGPT's assistance was invaluable in creating new problems efficiently. Designing algorithmic problems taught me the art of crafting challenges that maintain clarity while testing algorithmic knowledge.
