# %% [markdown]
# Q1: The Subset Sum Problem is a classic problem in computer science and mathematics. Given a set of positive integers and a target sum, the task is to determine whether there exists a subset of the integers that adds up to the given target sum.
#
# A. Is the Subset Sum Problem in P? If so, prove it.
#
# B. Suppose we restrict the integers in the set to be either 0 or 1. We call this the 0-1 Subset Sum Problem. Is the 0-1 Subset Sum Problem in NP? If so, prove it.
#
# C. Is the 0-1 Subset Sum Problem NP-complete? If so, prove it.

# %% [markdown]
# Solution:
# A. Is the Subset Sum Problem in P? If so, prove it.
# The Subset Sum Problem is not in P. It is known to be NP-complete. Here's a simple example:
# Given a set of positive integers: {2, 4, 7, 10, 15} and a target sum of 18, you need to determine whether there exists a subset of these integers that adds up to 18. In this case, the solution is "Yes," as the subset {2, 4, 7, 5} sums up to 18. However, the general approach to finding such a subset involves trying all possible combinations, which grows exponentially with the size of the input.
#
# B. Is the 0-1 subset sum problem an NP problem? If so, prove it.
# Yes, the 0-1 subset sum problem is an NP problem. We can apply a polynomial time verification algorithm to verify it.
# Given a set of 0 and 1 indicating whether each item in the set contains (1) or not (0), and a target sum, we can easily verify that the sum of the subset is indeed equal to the target sum by the following algorithm:
# 1. Start by setting the target sum to zero.
# 2. For each element in the set, if the corresponding value is 1, add that element's value to the target sum.
# 3. After all elements have been processed, check if the target sum is equal to the given target sum.
# For example, consider the set {0, 1, 0, 1, 1} and a target sum of 3. The algorithm can easily verify that the subset {1, 1, 1} sums up to 3.
#
# C. Is the 0-1 Subset Sum Problem NP-complete? If so, prove it.
# The 0-1 Subset Sum Problem is not NP-complete. It is a special case of the more general Subset Sum Problem, which is known to be NP-complete.
# The general Subset Sum Problem allows input values that are not limited to 0 and 1, making it more complex. The 0-1 Subset Sum Problem is a simplified version where the input values are restricted to 0 and 1, which makes it easier to solve. Since it's not harder than the NP-complete problem, it is not NP-complete.
# In summary, the 0-1 Subset Sum Problem is in NP but not NP-complete, while the general Subset Sum Problem is NP-complete.

# %% [markdown]
# Q2:Given a graph, is there a cycle that visits each vertex exactly once and returns to the starting vertex (Hamiltonian cycle)?
# Complexity: Prove that Hamiltonian Cycle is NP-complete.

# %% [markdown]
# Solution: Proving that the Hamiltonian Cycle problem is NP-complete involves two steps:
#
# 1. Show that Hamiltonian Cycle is in NP.
# 2. Reduce a known NP-complete problem to Hamiltonian Cycle.
#
# Step 1: Show that Hamiltonian Cycle is in NP
#
# To prove that Hamiltonian Cycle is in NP, we need to demonstrate that given a solution (a Hamiltonian cycle), we can efficiently verify its correctness. In the case of Hamiltonian Cycle, we can easily verify a solution as follows:
# Given a graph and a sequence of vertices, we can check whether the sequence forms a cycle by ensuring that it starts and ends at the same vertex, and it visits each vertex exactly once. This verification can be done in polynomial time. Hence, Hamiltonian Cycle is in NP.
#
# Step 2: Reduce a known NP-complete problem to Hamiltonian Cycle
#
# To prove the NP-completeness of Hamiltonian Cycle, we need to reduce a known NP-complete problem to Hamiltonian Cycle. One well-known NP-complete problem is the 3-SAT problem, which involves Boolean satisfiability.
# The 3-SAT problem: Given a Boolean formula in conjunctive normal form (CNF) with clauses containing at most 3 literals, is there an assignment of truth values to variables that makes the formula true?
# Now, we'll reduce 3-SAT to Hamiltonian Cycle. This reduction will show that if we can solve Hamiltonian Cycle, we can solve 3-SAT, making Hamiltonian Cycle NP-complete.
# Reduction from 3-SAT to Hamiltonian Cycle:
# For each variable xi in 3-SAT, create two vertices, xi and ¬xi, in the Hamiltonian Cycle instance.
# For each clause C in 3-SAT, create a gadget consisting of three vertices, one for each literal in the clause. Connect these vertices as follows:
# If the literal is positive, connect it to the corresponding variable vertex.
# If the literal is negated, connect it to the negation of the corresponding variable vertex.
# Add edges between all the gadgets and variable vertices to ensure connectivity.
# Add a starting and ending vertex to the graph, and connect the starting vertex to all variable vertices and the ending vertex to all clause gadgets.
# The reduction ensures that there is a Hamiltonian cycle in the resulting graph if and only if there is a satisfying assignment for the 3-SAT instance.
# Since 3-SAT is NP-complete, and we've shown a polynomial-time reduction from 3-SAT to Hamiltonian Cycle, it follows that Hamiltonian Cycle is also NP-complete.

# %% [markdown]
# Q3:A company has been hired to perform a series of jobs at different locations in a city. Each job takes one day to complete. The company has multiple teams and can hire additional teams as needed. However, there are constraints on job scheduling. For instance, if two jobs are in the same neighborhood, they must be scheduled on different days. The company needs to determine if a given set of jobs can be completed within a specified number of days, subject to the scheduling constraints.
#
# Part 1:
#
# Define the decision problem and the constraints involved in this job scheduling problem.
# Show that this problem is in the NP class by explaining how a proposed schedule can be efficiently verified.
# Propose a reduction to a known NP-complete problem. Explain how to transform an instance of the job scheduling problem into an instance of the chosen NP-complete problem.
# Prove that the proposed reduction is valid by demonstrating that a solution to the job scheduling problem corresponds to a solution to the chosen NP-complete problem instance.
# Part 2:
#
# Assume that you have successfully proven that the problem is NP-complete in Part 1. Now, consider the following:
#
# If a polynomial-time algorithm were discovered to solve this job scheduling problem, what implications would it have on the P vs. NP problem?
# Can you suggest an alternative approach to solving the job scheduling problem that might be more efficient than a direct search, given its NP-complete nature?

# %% [markdown]
# Solution:
# Part 1:
# 1. Define the decision problem and constraints:
# The decision problem is to determine whether a given set of jobs can be completed within a specified number of days while adhering to certain constraints. For example, if two jobs are in the same neighborhood, they must be scheduled on different dates to avoid conflicts.
#
# 2. Show that it is of type NP:
# Proposed schedules can be effectively verified. Given a schedule and constraints, we can check in polynomial time whether the constraints are satisfied and whether the total number of days matches the specified number. For example, if we are given a schedule where two jobs from the same community are assigned to the same day, we can quickly identify constraint violations.
#
# 3. We simplify it into a simple np problem:
# This problem can be reduced to the "sum of subsets problem", which is a known NP-complete problem. In the subset sum problem, given a set of integers and a target sum, we need to determine whether there is a subset that adds up to the target sum.
#
# Let's say we have three neighborhood-related jobs
# Job 1: Area A
# Job 2: Area B
# Job 3: Area A
# We assign integers to these jobs as follows:
# Homework 1: Integer 1
# Homework 2: Integer 2
# Homework 3: Integer 1
# And our total number of days is 3. If we can schedule these jobs within 3 days while ensuring that jobs in the same neighborhood are not scheduled on the same day, then it is equivalent to finding a subset of integers that sum to 3, which is equivalent to solving the subset sum problem. On the contrary, if we find a solution to the subset sum problem whose sum is 3, it means that we can schedule these jobs in 3 days without violating any constraints.
#
# part 2:
#
# If a polynomial time algorithm is discovered to solve the job scheduling problem, it means P = NP. Since we have shown that the job scheduling problem is NP-complete by reducing to a subset-sum problem, finding a polynomial-time algorithm means that the NP-complete problem can be solved in polynomial time.

# %% [markdown]
# Q4:The problem discussed is a modified version of the Traveling Salesman Problem (TSP), known as the Randomized TSP. In this problem, there is a set of n cities that need to be visited, and the goal is to find the shortest tour that covers all cities. However, there is a twist in Randomized TSP; there are multiple paths between each pair of cities, and you must randomly choose one of these paths at each step of the tour. The paths have a random length, and the lengths of the paths follow a known probability distribution.
#
# A) If we are given n cities connected by m random paths with known probability distributions for path lengths, what is the expected length of the shortest tour in the Randomized TSP?
#
# B) Is it possible to design a polynomial-time randomized algorithm that finds a tour in the Randomized TSP? The tour's length should not be more than 10% longer than the expected length determined in part A, with high probability.
#
# C) The algorithm designed in part B trades-off between the running time and the quality of the tour. As the number of cities and paths increases, the algorithm's performance changes, and the trade-offs become more complex.

# %% [markdown]
# Solution:
# A:Define the random variables: Let X be the random variable representing the length of the shortest tour in the Randomized TSP.
#
# Consider all possible ways to visit the n cities, forming permutations of the cities. There are n! (n factorial) such permutations.
#
# For each permutation (i.e., a specific order in which the cities are visited), calculate the total length of the tour, considering the random paths chosen at each step. The length of the tour is the sum of the random path lengths for each pair of consecutive cities in the chosen order.
#
# Calculate the probability of each permutation occurring. This depends on the specific probability distributions for the path lengths between cities.
#
# Calculate the expected value (mean) of the random variable X, which is the expected length of the shortest tour. You can use the following formula:
#
# E(X) = Σ [P(π) * L(π)]
#
# E(X) is the expected value of the shortest tour length.
# Σ is the sum of all permutations π.
# P(π) is the probability of the permutation π occurring.
# L(π) is the length of the tour for the permutation π.
#
# B:One possible way to solve this problem is to use a variant of stochastic TSP called "Probabilistic TSP". In this approach, we can randomly sample path selection at each step and then run the standard TSP algorithm on each sampled tour. This can be done in polynomial time if the number of samples is manageable.
#
# We can design your algorithm as follows:
#
# 1. The route selection for each pair of cities is randomly sampled based on a known probability distribution.
#
# 2. Run a traditional TSP algorithm (such as nearest neighbor or minimum spanning tree-based algorithm) on each sampled path selection to find tours.
#
# 3. Repeat steps 1 and 2 for enough iterations.
#
# 4. Calculate the average stroke length of all strokes obtained in step 2.
#
# The algorithm should find tours that are close to the expected length, since we are essentially averaging many possible path choices. However, it may not guarantee that the tour time will be extended by up to 10%, and the quality of the tour will depend on the number of iterations and the quality of the sampling procedure.
#
# C:The trade-off between the running time and tour quality of the algorithm designed in Part B depends on several factors, including the number of cities and routes, the number of iterations, and the complexity of the TSP algorithm used in step 2.
#
# As the number of cities and paths increases, the number of possible path choices increases exponentially, making the algorithm slower. The quality of the tour may improve with more iterations, but this comes at the expense of increased run time.

# %% [markdown]
# Q5：You are a social media influencer with a wide network of followers on your favorite social platform. Your followers can be divided into two categories: "Fans" and "Followers-of-Fans." Each of your fans has their own set of followers, which makes them Followers-of-Fans in your extended network. You want to make sure that a message you post reaches as many users in your network as possible.
# Your followers, who are your "Fans." The followers of each of your fans (Followers-of-Fans).
#
# Design an efficient algorithm that selects a minimum number of Fans (including yourself) such that every user in your network (Fans and Followers-of-Fans) receives your message.
#
# a. Show that the problem "Social Media Spread" is NP-Complete by reducing a known NP-complete problem to it.
#
# b. Discuss whether it is more practical to decide if it is possible to reach all users in your network or to find the minimum set of Fans who can achieve this goal. Consider the trade-offs between these two approaches

# %% [markdown]
# Solution:
# a To show that the problem "Social Media Spread" is NP-complete, we can reduce it to a well-known NP-complete problem, such as the Set Cover problem.
#
# Set Cover Problem: Given a universe U of elements and a collection C of subsets of U, find the minimum number of sets in C such that their union equals U.
#
# Now, let's reduce the Set Cover problem to the Social Media Spread problem:
#
# Universe U corresponds to all the users in your extended network, including Fans and followers of fans.
#
# The collection C corresponds to the set of Fans and their Followers-of-Fans, where each Fan and their Followers-of-Fans form a subset.
#
# The objective is to select the minimum number of Fans (and you) to ensure that your message reaches every user in the network (U).
# The Set Cover problem is known to be NP-Complete, and by reducing it to the Social Media Spread problem, we demonstrate that "Social Media Spread" is also NP-Complete.
#
# b Deciding if it's possible to reach all users:
# Pros:
# Simplicity: This approach involves checking if it's theoretically possible to reach all users in your network. If it's not possible, you can avoid the computational complexity of finding a minimum set of Fans.
# No need to identify specific Fans: You don't need to identify or select specific Fans, which might be challenging in some cases.
# Cons:
# Lack of optimization: This approach doesn't guarantee the most efficient or cost-effective way to reach all users. It may lead to unnecessary overexposure to certain Fans or neglect others.
# Finding the minimum set of Fans:
# Pros:
# Optimization: This approach aims to minimize the number of Fans to reach all users, making it more cost-effective and efficient.
# Targeted reach: You can specifically select Fans who have a wider reach or influence, ensuring better coverage.
# Cons:
# Computational complexity: Identifying the minimum set of Fans is an NP-Complete problem, which can be computationally expensive, especially if your network is large.
# The choice between the two approaches depends on the specific context and constraints. If your network is relatively small, it might be practical to find the minimum set of Fans. However, for very large networks, it may be more feasible to check if it's theoretically possible to reach all users and only pursue optimization when necessary. It's essential to balance computational complexity, resource constraints, and the desired level of optimization in your decision.

# %% [markdown]
# Q6:You are in charge of managing the feeding schedule for a zoo with various exotic animals. The zoo has ne lions, nt tigers, nz zebras, and ng gorillas. To ensure the health of the animals, you need to distribute three types of food: f1 kg of fish, f2 kg of meat, and f3 kg of fruits. Each lion eats only fish, each tiger eats only meat, each zebra eats only fruits, and each gorilla eats a combination of fish, meat, and fruits. Each animal requires one kilogram of food to stay fed for a day.
#
# Given the constraints, develop an algorithm that determines whether you have enough food to feed all the animals for a week. Your algorithm should reduce the problem to a network flow. Prove the correctness of your algorithm.

# %% [markdown]
# Solution:
# Algorithm:
#
# 1. Construct a graph G and capacities c as follows:
# Vertices:
# Create vertices vl, vt, vz, and vg. These correspond to lions, tigers, zebras, and gorillas.
# Create vertices uf1, uf2, and uf3. These correspond to types of food: fish, meat, and fruits.
# Create a source s and sink t.
# Edges:
# Create edges from s to uf1, uf2, and uf3 with capacities f1, f2, and f3, respectively.
# Create edges from vl, vt, vz, and vg to t with capacities ne, nt, nz, and ng, respectively.
# For each type of food, create an edge from that food's vertex to the vertex of each animal that eats it, with capacity 1.
# 2. Solve max flow on G and c.
# Apply a max-flow algorithm (such as Ford-Fulkerson) on the constructed graph with the given capacities.
# 3. Return “Yes" if and only if the size of the flow is 7 * (ne + nt + nz + ng):
# If the maximum flow in the network equals 7 * (ne + nt + nz + ng), then there is enough food to feed all the animals for a week. Otherwise, it means there is not enough food for at least one animal.
#
# Proof of Correctness:
#
# If the algorithm returns "Yes," it means that the maximum flow in the network is equal to the total amount of food required for a week by all animals.
# If there is enough food to feed all the animals for a week, there exists a flow in the network that satisfies the capacities of all edges. The algorithm finds the maximum flow, and if it is equal to 7 * (ne + nt + nz + ng)then it concludes that there is enough food for a week.

# %% [markdown]
# Q7:You are given an undirected graph with nodes labeled from 1 to N. Each node has an associated in-degree bound, denoted by an array in_degree_bounds, where in_degree_bounds[i] represents the maximum in-degree allowed for node i.
#
# Your task is to orient the edges of the graph in a way that respects the in-degree bounds or determine if it is impossible to do so.
#
# Write a function or algorithm to solve this problem. If a valid orientation exists, return the oriented graph. Otherwise, indicate that it is not possible.

# %%
#solution code
import heapq

def orient_graph(N, in_degree_bounds):
    in_degree = [0] * (N + 1)
    oriented_graph = [[] for _ in range(N + 1)]
    priority_queue = []

    for i in range(1, N + 1):
        in_degree[i] = in_degree_bounds[i - 1]
        if in_degree[i] == 0:
            heapq.heappush(priority_queue, i)

    while priority_queue:
        node = heapq.heappop(priority_queue)

        if in_degree[node] == 0:
            continue

        neighbors = [i for i in range(1, N + 1) if i != node and in_degree[i] > 0]
        if not neighbors:
            return "It is not possible to orient the graph."

        neighbor = max(neighbors, key=lambda x: in_degree_bounds[x - 1])

        oriented_graph[neighbor].append(node)
        in_degree[node] -= 1
        in_degree[neighbor] -= 1

        if in_degree[neighbor] == 0:
            heapq.heappush(priority_queue, neighbor)

    if any(in_degree[i] > 0 for i in range(1, N + 1)):
        return "It is not possible to orient the graph."

    return oriented_graph

# Example usage:
N = 4
in_degree_bounds = [2, 1, 1, 1]
result = orient_graph(N, in_degree_bounds)
print(result)
# Out:
# It is not possible to orient the graph.

# %% [markdown]
# Q8:You are consulting for a financial institution that processes a large number of financial transactions daily. To ensure the security of their system, they have implemented transaction logging software. The log file records, for each user u and each minute m, the transaction amount A(u,m) initiated by user u during minute m. If a user did not initiate any transaction during a minute, the value is set to the null symbol ⊥.
#
# Recently, the financial institution discovered that a series of fraudulent transactions occurred over t consecutive minutes, with each transaction being of a specific amount a1 a2 a3 ... at, The management suspects that a small coalition of users might have collectively carried out this fraudulent activity.
#
# The task is to determine whether there exists a suspicious coalition of k users who, collectively, initiated transactions of amounts a1 a2 a3 ... at at the appropriate times. A suspicious coalition is defined as a subset
# S of users such that, for each minute m from 1 to t, there is at least one user u∈S for which A(u,m)=am
#
# The Fraudulent Coalition Problem asks: Given the collection of all transaction amounts A(u,m), and a number k, is there a suspicious coalition of size at most k that could have collectively carried out the fraudulent transactions?

# %% [markdown]
# Solution:
# 1. Formulate as a Graph Problem:
# Treat each user as a node in a graph.
# Create edges between users who initiated transactions of the same amount in the same minute.
# 2. Enumerate Combinations:
# Enumerate all possible combinations of k users from the graph.
# 3. Check for Suspicious Coalition:
# For each combination, check if there is at least one user in the coalition for each minute m such that A(u,m)=am
# If such a coalition exists, then it's a suspicious coalition.

# %%
from itertools import combinations

def is_fraudulent_coalition(graph, amounts, k):
    for coalition in combinations(graph.nodes, k):
        valid_coalition = True
        for minute in range(1, len(amounts) + 1):
            valid_user_found = any(graph[node][minute] == amounts[minute - 1] for node in coalition)
            if not valid_user_found:
                valid_coalition = False
                break
        if valid_coalition:
            return True
    return False

# %% [markdown]
# Summary:
#
# 1. NP Problems (Non-deterministic Polynomial time):
#
# Definition: NP problems are decision problems for which the solutions can be verified quickly, but finding a solution may require an exponential amount of time.
#
# Gains:
#
# Efficient Verification: The primary gain is the ability to efficiently verify solutions. This is crucial in practical scenarios where checking a solution is much easier than finding one.
# Applications:
#
# Cryptography: Many problems related to number theory, such as factoring large numbers, are in NP. This is exploited in cryptographic algorithms like RSA, where the difficulty of factoring large numbers forms the basis of the security.
#
# Optimization: NP problems often model real-world optimization challenges. For example, the Traveling Salesman Problem (TSP) has applications in logistics, route planning, and network design.
#
# Scheduling: Problems like the Job Scheduling or Satisfiability Problem have applications in scheduling tasks, resource allocation, and planning.
#
# 2. NPC Problems (NP-complete):
#
# Definition: NP-complete problems are a subset of NP problems that are both in NP and at least as hard as the hardest problems in NP. If a polynomial-time algorithm exists for any NP-complete problem, then it can be applied to all problems in NP.
#
# Gains:
#
# Theoretical Understanding: Identifying NP-complete problems provides a deep theoretical understanding of the inherent difficulty in solving certain types of problems. The concept of NP-completeness allows us to categorize problems based on their computational complexity.
# Applications:
#
# Reduction Techniques: The concept of NP-completeness is crucial in reduction techniques. Solving an NP-complete problem efficiently would imply solving all problems in NP efficiently, leading to a better understanding of the boundaries of computation.
#
# Algorithm Design: Insights from NP-complete problems often guide the design of approximation algorithms, heuristics, and strategies for dealing with computationally hard problems in practice.
#
# Problem Solving Strategies: Recognizing NP-completeness helps in developing strategies to cope with intractable problems, such as dividing large problems into smaller, more manageable subproblems.
#
# 3. NP-hard Problems:
#
# Definition: NP-hard (Non-deterministic Polynomial-time hard) problems are at least as hard as the hardest problems in NP, but they may not necessarily be in NP. Unlike NP-complete problems, there is no requirement for NP-hard problems to be quickly verifiable.
#
# Gains:
#
# Benchmark for Hardness: NP-hard problems serve as benchmarks for computational hardness. They help in understanding problems that are inherently difficult and may not have efficient solutions.
# Applications:
#
# Algorithm Analysis: NP-hard problems are often used in the analysis of algorithms to establish lower bounds on the complexity of certain problems. This is essential for determining the limits of what can be efficiently computed.
#
# Heuristic Development: While NP-hard problems are not guaranteed to have polynomial-time solutions, they provide a basis for developing heuristics and approximation algorithms to find near-optimal solutions in practice.
#
# Reduction Techniques: Like NP-complete problems, NP-hard problems are important in reduction techniques. They are used to show the computational equivalence of different problems, aiding in the classification of problems based on their inherent complexity.
#
# Conclusion:
#
# Understanding NP and NPC problems is fundamental in both theoretical computer science and practical applications. While NP problems highlight the importance of efficient verification, NPC problems provide a framework for understanding and categorizing the computational complexity of various problems. The applications span diverse domains, including cryptography, optimization, scheduling, and problem-solving strategies, making the study of NP and NPC problems essential in algorithm design and computer science as a whole.
#
# Incorporating NP-hard problems into the discussion adds another layer to our understanding of computational complexity. NP-hard problems serve as benchmarks, aiding in algorithm analysis, heuristic development, and reduction techniques. While not necessarily quickly verifiable, these problems contribute to the broader landscape of computational theory and play a crucial role in establishing the limits of efficient computation.
