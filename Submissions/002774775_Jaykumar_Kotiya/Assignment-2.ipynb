# %% [markdown]
# ## Assignment-2

# %% [markdown]
# ###### Date: 10/08/2023
# ###### Name: Jaykumar Govind Kotiya
# ###### Subject: INFO 6205 Program Structure and Algorithms
# ###### NUID : 002774775

# %% [markdown]
# Question-1
#
# Find the Shortest Path in a Weighted Directed Graph
# Problem Statement:
# You are given a weighted directed graph and two distinct vertices, a source vertex S, and a destination vertex D. Your task is to find the shortest path from S to D in the given graph.
#
# Input Format:
#
# An integer N representing the number of vertices in the graph (1 <= N <= 10^5).
# An integer M representing the number of directed edges in the graph (1 <= M <= 10^5).
# N lines containing two integers each, U and V (1 <= U, V <= N), representing a directed edge from vertex U to vertex V.
# M lines containing three integers each, U, V, and W (1 <= U, V <= N, 1 <= W <= 1000), representing the weight of the directed edge from vertex U to vertex V.
# The source vertex S and destination vertex D are provided separately as two integers, where 1 <= S, D <= N and S ≠ D.
#
# Output Format:
#
# An integer representing the length of the shortest path from S to D. If there is no path from S to D, output -1.
#
# Sample Inputs and Outputs:
#
# Input 1:
# 6
# 8
# 1 2
# 1 3
# 2 3
# 2 4
# 3 5
# 4 6
# 5 4
# 6 5
# 1 2 2
# 1 3 1
# 2 3 3
# 2 4 4
# 3 5 2
# 4 6 1
# 5 4 3
# 6 5 2
# 1 4
#
# Output 1:
# 7
#
# Input 2:
# 4
# 4
# 1 2
# 1 3
# 2 3
# 3 4
# 1 2 2
# 1 3 1
# 2 3 3
# 3 4 4
# 2 4
#
# Output 2:
# -1
#
# Constraints:
#
# The graph is a directed graph with at most 10^5 vertices and 10^5 edges.
# The weight of each edge is between 1 and 1000.
# The source and destination vertices are distinct.
# The graph may not be strongly connected, i.e., there may not always be a path from S to D.
#
# Solution:
#
# To solve this problem, we can use Dijkstra's algorithm to find the shortest path from the source vertex S to all other vertices in the graph. Then, we can return the distance from S to the destination vertex D.
#
# Here's a pseudocode solution:
#
# function shortest_path(graph, S, D):
#     Initialize a distance array dist with infinity for all vertices except S (dist[S] = 0).
#     Create a priority queue Q to store vertices based on their distance.
#     Enqueue S into Q with a distance of 0.
#
#     while Q is not empty:
#         vertex = dequeue a vertex with the minimum distance from Q
#         for each neighbor of vertex:
#             new_distance = dist[vertex] + weight of edge from vertex to neighbor
#             if new_distance < dist[neighbor]:
#                 dist[neighbor] = new_distance
#                 enqueue neighbor into Q with new_distance
#
#     if dist[D] is still infinity, return -1 (no path exists from S to D)
#     else return dist[D]
#
# The correctness of Dijkstra's algorithm is well-established and proven. It guarantees finding the shortest path from the source vertex to all other vertices in the graph.

# %% [markdown]
# Question-2
#
# You are given a set of recurrence relations, each defined in the form T(n) = aT(n/b) + f(n), where a >= 1 and b > 1. Your task is to classify each recurrence relation into one of the four possible forms as described below. If the recurrence cannot be classified using the provided classification rules, you should indicate that it does not apply.
#
# Input Format:
#
# The input consists of multiple lines, each describing a recurrence relation.
# Each line contains three space-separated values: a, b, and f(n), where a is a positive integer, b is an integer greater than 1, and f(n) is a function describing the non-recursive part of the recurrence.
#
# Output Format:
#
# For each recurrence relation, output one of the following classifications:
# "Case 1", "Case 2", "Case 3", "Case 4", or "Does not apply".
# If the recurrence relation does not fit any of the cases, output "Does not apply".
#
# Sample Inputs and Outputs:
#
# Input:
# 3 3 n*log(n)
# 2 2 n^2
# 4 2 n^(1/2)
# 1 3 n^3
# 3 2 n
#
# Output:
# Case 1
# Case 4
# Does not apply
# Case 2
# Case 3
#
# Constraints:
# 1 <= a <= 1000
# 2 <= b <= 1000
# f(n) is a valid function, where 1 <= n <= 1000.
#
# Solution:
# Here's a pseudocode solution to classify the recurrence relations:
#
# for each recurrence relation (a, b, f(n)):
#     if f(n) is in the form n^c for some constant c and a = b^c:
#         output "Case 1"
#     elif f(n) is in the form n^c for some constant c and a < b^c:
#         output "Case 2"
#     elif f(n) is in the form n^c for some constant c and a > b^c:
#         output "Case 3"
#     else:
#         output "Does not apply"
#
#
# This solution can be proven by analyzing the given recurrence relation and checking if it fits into one of the four cases defined by the Master Theorem. The classification rules used in the pseudocode are consistent with the criteria for each case.

# %% [markdown]
# Question - 3
#
# Folk songs and holiday songs often have a unique structure where each verse builds upon the previous one by adding a new line while reusing the lines from previous verses. Your task is to develop an encoding method to represent these songs efficiently. Given that each line in the song has a length bounded by a constant c, and the entire song contains n words when sung, design an algorithm to encode the song using a script that has the shortest possible length f(n).
#
# Input Format:
#
# The input consists of a list of lines in the song.
# Each line is represented as a string.
# The total number of words in the song is n, where 1 <= n <= 1000.
# The length of each line (number of characters) is bounded by a constant c, where 1 <= c <= 100.
#
# Output Format:
#
# Output the encoded script that represents the song using the shortest possible length f(n).
#
# Sample Inputs and Outputs:
#
# Input: ["On the first day of Christmas,", "my true love sent to me", "A partridge in a pear tree.", "Two turtle doves,", "And a partridge in a pear tree.", "Three French hens,", "Two turtle doves,", "And a partridge in a pear tree.", "Four calling birds,", "Three French hens,", "Two turtle doves,", "And a partridge in a pear tree.", "Five golden rings,", "Four calling birds,", "Three French hens,", "Two turtle doves,", "And a partridge in a pear tree."]
#
# Output: ["On the first day of Christmas,", "my true love sent to me", "A partridge in a pear tree.", "Two turtle doves,", "Three French hens,", "Four calling birds,", "Five golden rings,"]
#
# Constraints:
#
# The length of each line is bounded by a constant c, where 1 <= c <= 100.
# 1 <= n <= 1000 (total words in the song).
#
# Solution:
# To encode the song efficiently, we can use the following pseudocode:
#
# def encode_folk_song(song_lines):
#
#     encoded_script = []
#     unique_lines = set()
#
#     for line in song_lines:
#         if line not in unique_lines:
#             encoded_script.append(line)
#             unique_lines.add(line)
#
#     return encoded_script
#
#
# This solution iterates through the song lines and adds each line to the encoded_script only if it has not been encountered before. Since folk songs reuse lines from previous verses, we eliminate duplicates, resulting in the shortest possible script. This approach is efficient and correct because it utilizes the property of these songs effectively.

# %% [markdown]
# Question - 4
#
# Given a binary tree, you need to design an algorithm to count the number of nodes with two children and the number of leaves in the tree. Your task is to prove by induction that the number of nodes with two children is exactly one less than the number of leaves in the binary tree.
#
# Input Format:
#
# The input is a binary tree represented as a list of nodes, where each node has a unique identifier, and its left and right children (if they exist) are represented by their identifiers. The input is a list of tuples, where each tuple contains the node identifier, the left child identifier, and the right child identifier. The input is guaranteed to be a valid binary tree.
#
# Output Format:
#
# The algorithm should return two integers: the count of nodes with two children and the count of leaves.
#
# Function Signature:
# def count_nodes(tree: List[Tuple[int, int, int]]) -> Tuple[int, int]:
#     pass
#
# Sample Inputs and Outputs:
# Input
# tree1 = [(1, 2, 3), (2, 4, None), (3, None, 5), (4, None, None), (5, None, None)]
#
# Output
# count_nodes(tree1) => (2, 3)
#
# Input
# tree2 = [(1, None, None)]
#
# Output
# count_nodes(tree2) => (0, 1)
#
# Input
# tree3 = [(1, 2, None), (2, None, None)]
#
# Output
# count_nodes(tree3) => (0, 1)
#
# Constraints:
#
# The input binary tree will have at most 10^4 nodes.
# Each node identifier is a unique positive integer.
# The binary tree is guaranteed to be valid, with no cycles.
#
# Correctness:
#
# Proving the correctness of the algorithm using mathematical induction.
#
# Base Case (n=1):
# For a tree with only one node, there are 0 nodes with two children and 1 leaf. The base case holds.
#
# Inductive Hypothesis:
# Assume that for any binary tree with n nodes, the algorithm correctly counts the number of nodes with two children and the number of leaves.
#
# Inductive Step:
# Now, consider a binary tree with n+1 nodes. We can divide this tree into two parts: a root node and two subtrees.
#
# 1. If the root node has two children, the number of nodes with two children increases by 1, and the number of leaves remains the same.
# 2. If the root node has only one child (either left or right), the number of leaves increases by 1, and the number of nodes with two children remains the same.
# 3. If the root node has no children, the number of leaves increases by 1, and the number of nodes with two children remains the same.
# In all cases, the difference between the number of nodes with two children and the number of leaves remains the same (1 less) as per the induction hypothesis.
#
# Thus, the algorithm correctly counts the number of nodes with two children and the number of leaves for any binary tree.

# %% [markdown]
# Question - 5
#
# You are given two sequences of integers, S of length n and S' of length m. Your task is to determine whether S' is a subsequence of S. A sequence S' is considered a subsequence of S if you can obtain S' by deleting certain elements from S while maintaining their relative order. In other words, if you can remove zero or more elements from S to get S', then S' is a subsequence of S. Write a function or algorithm that efficiently checks if S' is a subsequence of S and returns true if it is, and false otherwise.
#
# Input Format:
#
# An integer n (1 <= n <= 10^5): the length of sequence S.
# An integer m (1 <= m <= n): the length of sequence S'.
# A list of n integers representing sequence S.
# A list of m integers representing sequence S'.
#
# Output Format:
#
# A boolean value: true if S' is a subsequence of S, false otherwise.
#
# Sample Inputs and Outputs:
# Input:
# n = 7
# m = 4
# S = [3, 2, 5, 4, 7, 1, 6]
# S' = [2, 5, 7, 6]
#
# Output:
# true
#
# Input:
# n = 6
# m = 3
# S = [1, 2, 3, 4, 5, 6]
# S' = [6, 2, 4]
#
# Output:
# false
#
# Input:
# n = 5
# m = 2
# S = [1, 2, 3, 4, 5]
# S' = [3, 6]
#
# Output:
# false
#
# Constraints:
#
# - All elements in the sequences S and S' are integers.
# - The length of S (n) will be at most 10^5.
# - The length of S' (m) will be at most n.
# - The integers in the sequences are in the range [-10^9, 10^9].
#
# Solution:
# We can solve this problem efficiently by iterating through both sequences S and S' simultaneously and comparing their elements.
#
# Here's a pseudocode solution:
#
# function isSubsequence(S, S', n, m):
#     i = 0  -> Pointer for sequence S
#     j = 0  -> Pointer for sequence S'
#
#     while i < n and j < m:
#         if S[i] == S'[j]:
#             j += 1  -> Move to the next element in S'
#         i += 1  -> Always move to the next element in S
#
#     - If we reached the end of S', S' is a subsequence of S
#     return j == m
#
# Correctness:
# The algorithm iterates through both sequences, always advancing the pointer in S and, if there's a match, advancing the pointer in S'. If it successfully reaches the end of S', it means all elements in S' have been found in S in the same relative order, satisfying the definition of a subsequence. Thus, the algorithm is correct.

# %% [markdown]
# Question - 6
#
# You are given a course schedule represented as a directed acyclic graph (DAG) where courses are vertices, and directed edges represent prerequisites. Each vertex represents a course, and each directed edge (A, B) means course A is a prerequisite for course B. Implement an algorithm to find the minimum number of semesters required to complete all the courses while satisfying the prerequisite dependencies. Also, identify if it's impossible to complete all courses.
#
# Input Format:
#
# An integer N representing the number of courses (1 <= N <= 10^5).
# A list of directed edges (prerequisite pairs), where each edge is represented as (A, B), indicating course A is a prerequisite for course B.
# Output Format:
#
# An integer representing the minimum number of semesters required to complete all courses. If it's impossible to complete all courses due to cyclic dependencies, output -1.
#
# Sample Inputs and Outputs:
#
# Input:
# N = 6
# Prerequisites = [(1, 2), (1, 3), (2, 4), (2, 5), (3, 6)]
#
# Output:
# Minimum Semesters: 3
#
# Input:
# N = 4
# Prerequisites = [(1, 2), (2, 3), (3, 1)]
#
# Output:
# It's impossible to complete all courses.
#
# Constraints:
#
# The input graph is directed and acyclic (DAG).
# There can be isolated vertices (courses with no prerequisites).
# The vertices are represented by unique integers (course IDs).
#
# Solution:
# To solve this problem, we can use topological sorting to find the minimum number of semesters. We'll modify the standard topological sorting algorithm to keep track of semesters and dependencies:
#
# 1. Initialize an array in_degree of size N to store the in-degrees of each course.
# 2. Compute the adjacency-list representation of the graph.
# 3. Initialize a queue Q and add all courses with in-degree 0 to it.
# 4. Initialize a variable semesters to 0.
# 5. While Q is not empty:
#     For each course u in Q:
#     - Decrement the in_degree of u's prerequisites by 1.
#     - If any of u's prerequisites have an in-degree of 0, add them to Q.
#     Increment semesters by 1.
# 6. After the loop, if there are any courses with in-degrees greater than 0, it means there are cyclic dependencies, and we return -1. Otherwise, return semesters as the minimum number of semesters required.
#
# This algorithm ensures that each course is taken in a semester where all its prerequisites have been completed.
# If there are cyclic dependencies, the algorithm will identify it as there will be courses with in-degrees greater than 0, and it returns -1.

# %% [markdown]
# Question - 7
#
# Use Prim's algorithm to find a minimum spanning tree in a graph of your choice.
#
# Constraints:
#
# 1 ≤ n ≤ 1000 (number of nodes)
# 0 ≤ m ≤ n*(n-1)/2 (maximum number of edges)
# Solution:
#
# Prim's algorithm is used to find a minimum spanning tree (MST) in a weighted, connected, and undirected graph. It works by greedily selecting edges that connect the MST to a new node while ensuring that the MST remains connected. Here's a step-by-step explanation of Prim's algorithm:
#
# 1. Initialize an empty set MST to represent the minimum spanning tree and a set visited to keep track of visited nodes.
# 2. Choose a starting node s arbitrarily and add it to the visited set.
# 3. Initialize a priority queue (min-heap) pq with all edges incident to s.
# 4. Repeat the following steps until MST contains n-1 edges (where n is the number of nodes in the graph):
#
#    a. Pop the edge (u, v) with the smallest weight from the priority queue pq. If v is not in the visited set, add (u, v) to MST and mark v as visited by adding it to the visited set.
#
#    b. Add all edges incident to v that connect to unvisited nodes to the priority queue pq.
# 5. Return the MST as the minimum spanning tree of the graph.
#
# link: https://docs.google.com/document/d/1-8MjYsWO3M2q_Znn4NkbKKdUew8fpSEfs63kGn-eV3s/edit?usp=sharing
#
# Proof of Correctness:
#
# Prim's algorithm is a greedy algorithm, and it guarantees the correctness of the minimum spanning tree it produces. The algorithm selects edges with the smallest weight, ensuring that the tree remains connected while minimizing the total weight. By the end of the algorithm, it will have connected all nodes with the minimum possible weight, satisfying the properties of a minimum spanning tree.

# %% [markdown]
# Question - 8
#
# A shipping company operates a network of routes connecting various cities. Each route has a cost associated with it, which can change daily. The company wants to find the most cost-effective route between two given cities for a shipment. Develop an algorithm that efficiently determines the best route for a shipment and explain why your algorithm is efficient.
#
# Input Format:
#
# The input consists of the following:
# A list of cities (nodes) connected by routes.
# For each route, the start city, end city, and the cost of using that route.
# The start city and end city for the shipment.
# Output Format:
#
# The algorithm should output the most cost-effective route from the start city to the end city for the shipment.
#
# Sample Inputs and Outputs:
#
# Sample Input:
# cities = ["A", "B", "C", "D"]
# routes = [
#     ("A", "B", 5),
#     ("A", "C", 7),
#     ("B", "C", 3),
#     ("B", "D", 10),
#     ("C", "D", 2)
# ]
# start_city = "A"
# end_city = "D"
#
# Sample Output:
# Most cost-effective route from A to D: A -> B -> C -> D
# Total cost: 10
#
# Constraints:
#
# The number of cities (nodes) is at most 1,000.
# The number of routes (edges) is at most 10,000.
# The cost of each route is a positive integer.
#
# Solution:
#
# Formulate this as a graph problem. Create a weighted directed graph where each city is a node, and each route is an edge with a weight representing the cost. Use a single-source shortest path algorithm (e.g., Dijkstra's algorithm) to find the most cost-effective route from the start city to the end city. This algorithm has a time complexity of O((V+E)log(V)), where V is the number of cities and E is the number of routes.
#
# After finding the shortest path, you can reconstruct the route and calculate the total cost. The maximum profit in this problem is equivalent to finding the minimum cost route.
#
# Proof of Correctness:
#
# Dijkstra's algorithm is a well-established algorithm for finding the shortest path in a weighted directed graph. It guarantees that we find the minimum cost route from the start city to any other city in the graph. Therefore, it is correct for this problem.

# %% [markdown]
# Question - 9
#
# Let's find the shortest path from node A to node B using Breadth-First Search (BFS) in a simple graph.
#
# Graph:
#    A --- B
#    |     |
#    C --- D
#
#    solution:
#
# Input Format:
#
# The input consists of the following:
# A map of the city, represented as a graph with streets (edges) and intersections (nodes).
# Each street has a length (distance) associated with it.
# The location of charging stations in the city.
# The starting location of the EV owner (Node A).
# Output Format:
#
# The algorithm should output the shortest route from the starting location to the nearest charging station (Node B) for the EV owner to charge their vehicle.
# Sample Inputs and Outputs:
#
# Sample Input:
#
# City Map:
#    A --- B
#    |     |
#    C --- D
#
# Streets:
#    (A, B, 5)
#    (A, C, 2)
#    (B, D, 7)
#    (C, D, 3)
#
# Charging Stations: [D]
#
# Start Location: A
#
# Sample Output:
#
# Shortest Route from A to D (Charging Station): A -> C -> D
# Total Distance: 5
#
# Constraints:
#
# The number of intersections (nodes) in the city is at most 1,000.
# The number of streets (edges) connecting intersections is at most 10,000.
# The length of each street is a positive integer.
# The number of charging stations is at most 100.
# Solution:
#
# To find the shortest route for an EV owner to the nearest charging station, we can use Breadth-First Search (BFS) on the city map represented as a graph. Here's the algorithm:
#
# Start at the EV owner's current location (Node A) and initialize an empty queue for BFS traversal.
#
# Mark Node A as visited and enqueue it into the queue.
#
# Queue: [A]
# Visited: [A]
#
# Begin the BFS traversal loop:
#
# Dequeue the first node from the queue.
# Explore its neighbors (connected intersections) and calculate the distance to them.
# Check if any of the neighbors are equal to a charging station node (Node B). If yes, we've found the shortest route to a charging station.
#
# If a charging station node is not found among the neighbors, enqueue the unvisited neighbors and mark them as visited.
#
# Queue: [C, B]
# Visited: [A, B, C]
#
# Repeat steps 3-5 until we reach a charging station node (Node B).
#
# After reaching a charging station, backtrack to reconstruct the shortest route.
#
# The BFS traversal terminates since we found the shortest route to a charging station.
#
# Proof of Correctness:
#
# Breadth-First Search guarantees that we find the shortest route from the EV owner's starting location to the nearest charging station in the city map. Therefore, it is correct for this problem.

# %% [markdown]
# Question - 10
#
# You are given a weighted undirected graph representing cities and the distances between them. Your task is to find the minimum spanning tree (MST) of the graph using Kruskal's algorithm. The MST is a subset of the graph's edges that connects all the cities with the minimum total weight, without forming any cycles.
#
# Graph G: link : https://docs.google.com/document/d/1-8MjYsWO3M2q_Znn4NkbKKdUew8fpSEfs63kGn-eV3s/edit?usp=sharing
#
#
#          6
#    A ----------- B
#    | \         | \
#    |  2        |  5
#    |   \       |   \
#    |    \      |    \
#    |     \     |     \
#    |      \    |      \
#    |       \   |       \
#    C ----------- D ------ E
#    | 3     |   | 4     |  1
#    |       |   |       |
#    F ----- G   H ----- I
#         7          8
#
# In this graph:
#
# Nodes A, B, C, D, E, F, G, H, and I represent cities.
# The numbers on the edges represent the distances between the cities.
# You are tasked with finding the minimum spanning tree (MST) of this graph using Kruskal's algorithm.
#
# Input Format:
#
# The input consists of the following:
# A weighted undirected graph represented as a list of edges, where each edge is a triple (city1, city2, distance).
# The number of cities and the number of edges in the graph.
# City names are represented as letters (e.g., A, B, C), and distances are positive integers.
# Output Format:
#
# The algorithm should output the edges that form the minimum spanning tree (MST) and the total weight of the MST.
# Sample Inputs and Outputs:
#
# Sample Input:
#
# Number of Cities: 9
# Number of Edges: 14
#
# Edges:
# (A, B, 6)
# (A, C, 2)
# (A, D, 7)
# (B, C, 5)
# (B, E, 5)
# (C, D, 4)
# (C, F, 3)
# (D, E, 4)
# (E, G, 2)
# (E, H, 5)
# (F, H, 6)
# (G, H, 3)
# (G, I, 8)
# (H, I, 7)
#
#
# Sample Output:
#
# Minimum Spanning Tree (MST):
# (A, C, 2)
# (C, F, 3)
# (E, G, 2)
# (C, D, 4)
# (D, E, 4)
# (B, C, 5)
# (F, H, 6)
# (G, H, 3)
# Total Weight of MST: 29
#
# Constraints:
#
# The number of cities (nodes) is at most 1,000.
# The number of edges (connections between cities) is at most 10,000.
# The distance between cities is a positive integer.
#
# Solution:
#
# Kruskal's algorithm is used to find the minimum spanning tree (MST) in a weighted undirected graph. Here's a step-by-step explanation of the solution:
#
# Sort the edges of the graph in ascending order based on their weights.
#
# Initialize an empty set to represent the MST.
#
# Iterate through the sorted edges:
#
# If adding the current edge to the MST does not create a cycle, add it to the MST.
# Use a data structure, such as a disjoint-set (union-find), to check for cycles efficiently.
# Continue this process until the MST contains (number of cities - 1) edges.
#
# Output the edges in the MST and calculate the total weight of the MST.
#
#  Kruskal's algorithm can be established by noting that it consistently selects edges with the minimum weight that do not form cycles in the MST. By the time (number of cities - 1) edges have been added, the MST connects all cities without forming cycles, ensuring it is indeed a spanning tree with the minimum total weight.
